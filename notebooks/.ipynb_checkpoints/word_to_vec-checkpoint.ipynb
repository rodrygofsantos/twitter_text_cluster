# %%
import os

import collections

import matplotlib
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from unidecode import unidecode
import gensim


# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = (20.0, 20.0)

# %%
# base vars
datasets_path = '../datasets/'
csv_path = datasets_path +'csv/'
outputs_path = '../outputs/'

# %%
#show project dirs
p_dirs = [d for d in os.listdir(datasets_path) if os.path.isdir(os.path.join(datasets_path, d)) and not d.startswith('.')]
p_dirs
# Out:
# ['csv', 'tweets']

# %%
#show corpus files
corpus_path = datasets_path+'{0}/'.format(p_dirs[1])
cur_files = [e for e in os.listdir(corpus_path) if os.path.isfile(os.path.join(corpus_path, e)) and not e.startswith('.')]
cur_files
# Out:
# ['2019-11-06 21:50:52.267798.txt']

# %%
#get file info
cur_file_path = corpus_path+cur_files[0]
separator = '||'

tmp_text = '';
with open(cur_file_path, 'r') as file:
    tmp_text = file.read()
    file.close()

#text preparation
tmp_text = unidecode(tmp_text.lower()) #tirando  acentuação e colocando em letras minúsculas
tmp_text = ' '.join(tmp_text.splitlines()) #removendo \n

##tweets txt
tmp_text = tmp_text.split('||')

##gerando matriz esparsa
nltk.download('punkt')
tmp_text = [[f.lower() for f in word_tokenize(e)] for e in tmp_text]

tmp_text
# Out:
# [nltk_data] Downloading package punkt to /home/albrigs/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['@',
#   'arcenio_igor',
#   '@',
#   'immari_bitch',
#   'pior',
#   'que',
#   'tem',
#   'notebook',
#   'mesmo',
#   'mkkkkkkkk'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['o',
#   'unico',
#   'dia',
#   'que',
#   'eu',
#   'to',
#   'em',
#   'casa',
#   'e',
#   'preciso',
#   'do',
#   'notebook',
#   'pra',
#   'estudar',
#   ',',
#   'minha',
#   'irma',
#   'usa'],
#  ['aaaaaaaaaaah', 'meu', 'notebook', 'ta', 'funcionando', '!', '!', '!', '!'],
#  ['na',
#   'porra',
#   'do',
#   'celular',
#   'nem',
#   'adianta',
#   'jogar',
#   'pq',
#   'vai',
#   'fuder',
#   'ele',
#   'mais',
#   'ainda',
#   ',',
#   'e',
#   'o',
#   'notebook',
#   'nao',
#   'aguenta',
#   'nem',
#   'rodar',
#   '50',
#   'de',
#   'fps'],
#  ['preciso',
#   'comprar',
#   'um',
#   'notebook',
#   'ate',
#   '2000',
#   'reais',
#   'se',
#   'alguem',
#   'tiver',
#   'alguma',
#   'sugestao',
#   '.'],
#  ['fodase', 'vo', 'tirar', 'o', 'adesivo', 'da', 'camera', 'do', 'notebook'],
#  ['o',
#   'meu',
#   'notebook',
#   'nunca',
#   'me',
#   'fez',
#   'passar',
#   'tanta',
#   'raiva',
#   'quanto',
#   'ele',
#   'ta',
#   'fazendo',
#   'hoje',
#   'meu',
#   'deus',
#   'do',
#   'ceu',
#   'que',
#   'odio',
#   'eu',
#   'nao',
#   'tenho',
#   'sorte',
#   'pra',
#   'nada',
#   'nessa',
#   'vida'],
#  ['rt',
#   '@',
#   'hilu_hilu',
#   ':',
#   'mas',
#   'gente',
#   'falando',
#   'serio',
#   ':',
#   'eu',
#   'ainda',
#   'nao',
#   'cheguei',
#   'em',
#   'nem',
#   '50',
#   '%',
#   'da',
#   'minha',
#   'vaquinha',
#   'pra',
#   'recuperar',
#   'os',
#   'itens',
#   'que',
#   'me',
#   'roubaram',
#   '.',
#   'o',
#   'noteboo',
#   '...'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['rt',
#   '@',
#   'borelanjo',
#   ':',
#   'stickers',
#   'pra',
#   'customizar',
#   'o',
#   'notebook',
#   '#',
#   'ubuntu',
#   '#',
#   'linux',
#   'https',
#   ':',
#   '//t.co/s5ucdks3au'],
#  ['nessas', 'horas', 'que', 'e', 'bom', 'n', 'ter', 'tv', 'nem', 'notebook'],
#  ['ai',
#   'q',
#   'saco',
#   'na',
#   'hora',
#   'q',
#   'eu',
#   'mais',
#   'preciso',
#   'essa',
#   'porra',
#   'de',
#   'notebook',
#   'quer',
#   'ficar',
#   'de',
#   'graca'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['o',
#   'vasco',
#   'ja',
#   'levou',
#   'gol',
#   '?',
#   'nem',
#   'abri',
#   'ainda',
#   'o',
#   'premiere',
#   'no',
#   'notebook'],
#  ['segunda',
#   'vez',
#   'no',
#   'dia',
#   'que',
#   'meu',
#   'notebook',
#   'trava',
#   ',',
#   'to',
#   'ficando',
#   'nervosa'],
#  ['hoje',
#   'eu',
#   'desliguei',
#   'o',
#   'notebook',
#   'do',
#   'professor',
#   'sem',
#   'querer',
#   'boa',
#   'noite'],
#  ['formataram', 'meu', 'notebook', 'k', 'que', 'odio'],
#  ['meu',
#   'laptop',
#   'novo',
#   'chegou',
#   'e',
#   'em',
#   'breve',
#   'eu',
#   'finalmente',
#   'vou',
#   'ter',
#   'omnisphere',
#   'e',
#   'tal',
#   'mas',
#   'os',
#   'ultimos',
#   'beats',
#   'que',
#   'eu',
#   'tenho',
#   'feito',
#   'no',
#   'notebook',
#   'antigo',
#   '...',
#   '.',
#   'shhh'],
#  ['o',
#   'jeito',
#   'que',
#   'eu',
#   'chego',
#   'em',
#   'casa',
#   'e',
#   'sento',
#   'direto',
#   'na',
#   'frente',
#   'do',
#   'notebook',
#   'pra',
#   'terminar',
#   'de',
#   'fazer',
#   'as',
#   'coisas',
#   'da',
#   'faculdade',
#   'e',
#   'diferente'],
#  ['rt',
#   '@',
#   'henriqvesucks',
#   ':',
#   'eu',
#   'com',
#   'o',
#   'notebook',
#   'travando',
#   'so',
#   'com',
#   'o',
#   'word',
#   'e',
#   'o',
#   'chrome',
#   'aberto',
#   'https',
#   ':',
#   '//t.co/nzdxe0zxxh'],
#  ['meu', 'notebook', 'ta', 'uma', 'porra'],
#  ['que',
#   'sufoco',
#   'para',
#   'finalizar',
#   'esse',
#   'trabalho',
#   ',',
#   'ate',
#   'no',
#   'bar',
#   'fomos',
#   'parar',
#   'usar',
#   'o',
#   'notebook',
#   'hahaha'],
#  ['to',
#   'precisando',
#   'trocar',
#   'de',
#   'notebook',
#   ',',
#   'alguma',
#   'recomendacao',
#   'de',
#   'bom',
#   'custo',
#   'x',
#   'beneficio',
#   '?'],
#  ['@',
#   'lmjsweetc',
#   'acho',
#   'que',
#   'nao..so',
#   'quem',
#   'tem',
#   'computador',
#   'ou',
#   'notebook',
#   ',',
#   'e',
#   'do',
#   'mesmo',
#   'jeito',
#   'acho',
#   'que',
#   'voce',
#   'nao',
#   'ia',
#   'querer',
#   'copiar',
#   'e',
#   'colar',
#   'no',
#   'word',
#   'coisas',
#   'kk'],
#  ['se',
#   'meu',
#   'notebook',
#   'n',
#   'fosse',
#   'tao',
#   'merda',
#   'minha',
#   'vida',
#   'estaria',
#   '30',
#   '%',
#   'melhor'],
#  ['bah',
#   'quando',
#   'eu',
#   'preciso',
#   'esse',
#   'notebook',
#   'se',
#   'faz',
#   'puta',
#   'merda'],
#  ['namoral', 'notebook', 'eh', 'muito', 'paia', 'vaisefude'],
#  ['meu',
#   'notebook',
#   'bicho',
#   '.',
#   'ninguem',
#   'encosta',
#   'no',
#   'meu',
#   'notebook',
#   'sem',
#   'uma',
#   'assinatura',
#   'no',
#   'cartorio',
#   '.',
#   'https',
#   ':',
#   '//t.co/3kschrfhnc'],
#  ['eu',
#   'podia',
#   'estar',
#   'fazendo',
#   'meu',
#   'tcc',
#   ',',
#   'mas',
#   'resolvi',
#   'entrar',
#   'no',
#   'tt',
#   'pelo',
#   'notebook',
#   ',',
#   'e',
#   'agora',
#   'nao',
#   'saio'],
#  ['@', 'juciarmy', 'naoo', 'nega', 'kkkkkkkk', ',', 'to', 'pelo', 'notebook'],
#  ['eu',
#   'so',
#   'quero',
#   'meu',
#   'celular',
#   'novo',
#   'logo',
#   'nao',
#   'aguento',
#   'mais',
#   'ficar',
#   'em',
#   'notebook',
#   'so',
#   'as',
#   'vezes',
#   'e',
#   'celular',
#   'dos',
#   'outros'],
#  ['as', 'fotos', 'que', 'tem', 'no', 'meu', 'notebook', 'kkkkk'],
#  ['@',
#   'indiiantv',
#   'notebook',
#   ':',
#   '4gb',
#   'ram',
#   'ddr3',
#   'intel',
#   'celeron',
#   'n3360',
#   '1',
#   'tera',
#   'hd',
#   'sem',
#   'placa',
#   'de',
#   'video'],
#  ['@',
#   'lmjsweetc',
#   'nao',
#   'consigo',
#   '?',
#   '?',
#   '?',
#   'faz',
#   '8',
#   'horas',
#   'que',
#   'estou',
#   'tentando',
#   'fazer',
#   'esse',
#   'trabalho',
#   ',',
#   'ou',
#   'achar',
#   'feito',
#   'louca',
#   'alguem',
#   'que',
#   'tenha',
#   'notebook/computador',
#   'e',
#   'nao',
#   'acho',
#   'k'],
#  ['o',
#   'meu',
#   'maior',
#   'erro',
#   'do',
#   'ano',
#   'foi',
#   'ter',
#   'vendido',
#   'o',
#   'resto',
#   'do',
#   'meu',
#   'notebook',
#   ',',
#   'por',
#   'mais',
#   'ruim',
#   'q',
#   'fosse',
#   'ainda',
#   'dava',
#   'para',
#   'eu',
#   'digitar',
#   'um',
#   'trabalho'],
#  ['@',
#   'alienvoodoodoll',
#   'sera',
#   'que',
#   'roda',
#   'no',
#   'meu',
#   'notebook',
#   'podi',
#   '?'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['@',
#   'bolsodetigresa',
#   'eu',
#   'tambem',
#   'sou',
#   'adepta',
#   'do',
#   'modo',
#   'claro',
#   ':',
#   'd',
#   '(',
#   'acho',
#   'que',
#   'o',
#   'escuro',
#   'so',
#   'faz',
#   'sentido',
#   'no',
#   'escuro',
#   ',',
#   'e',
#   'eu',
#   'nao',
#   'uso',
#   'celular/notebook',
#   'no',
#   'escuro',
#   ')',
#   '.',
#   'bora',
#   'la',
#   'ser',
#   'antissocial',
#   'juntas',
#   '!',
#   'hahahaha'],
#  ['hoje',
#   'que',
#   'eu',
#   'resolvi',
#   'estudar',
#   'fsq',
#   '2',
#   'meu',
#   'notebook',
#   'travou',
#   'todo',
#   ',',
#   'acho',
#   'que',
#   'ele',
#   'me',
#   'entende',
#   'e',
#   'tambem',
#   'nao',
#   'gosta',
#   'desse',
#   'conteudo',
#   'chato'],
#  ['@',
#   'fabioquadros_',
#   'eu',
#   'sofrendo',
#   'por',
#   'dez',
#   'dias',
#   'esperando',
#   'o',
#   'hd',
#   'novo',
#   'do',
#   'meu',
#   'notebook',
#   '.',
#   'boa',
#   'sorte'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['eu',
#   'sei',
#   'de',
#   'tudo',
#   'que',
#   'eu',
#   'tenho',
#   'que',
#   'fazer',
#   'ate',
#   'pegar',
#   'o',
#   'notebook',
#   ',',
#   'ai',
#   'meu',
#   'colega',
#   'eu',
#   'nao',
#   'lembro',
#   'de',
#   'nada'],
#  ['@',
#   'immari_bitch',
#   '@',
#   'gab_uzumaki',
#   'compra',
#   'um',
#   'notebook',
#   'da',
#   'xaiomy'],
#  ['rt',
#   '@',
#   'cellooo2',
#   ':',
#   'no',
#   'auge',
#   'da',
#   'producao',
#   ',',
#   'o',
#   'notebook',
#   'achou',
#   'de',
#   'travar'],
#  ['tem',
#   'como',
#   'fica',
#   'com',
#   'notebook',
#   'ligado',
#   'fazendo',
#   'as',
#   'coisas',
#   "'",
#   'nao',
#   'tem',
#   'como',
#   'a',
#   'porra',
#   'ta',
#   'lento',
#   'pra',
#   'caraca'],
#  ['eu',
#   'com',
#   'o',
#   'notebook',
#   'travando',
#   'so',
#   'com',
#   'o',
#   'word',
#   'e',
#   'o',
#   'chrome',
#   'aberto',
#   'https',
#   ':',
#   '//t.co/nzdxe0zxxh'],
#  ['gente',
#   'eu',
#   'perdi',
#   'o',
#   'arquivo',
#   '10x',
#   ',',
#   'e',
#   'na',
#   'ultima',
#   'corrompeu',
#   'meu',
#   'notebook',
#   '.',
#   'fiz',
#   'do',
#   'zero',
#   ',',
#   'deu',
#   'certo',
#   '!',
#   'em',
#   'nome',
#   'de',
#   'jesus',
#   'amem',
#   '!'],
#  ['unico',
#   'fake',
#   'da',
#   'flatt',
#   'que',
#   'eu',
#   'lembro',
#   'era',
#   'o',
#   'mandellimonk',
#   '.',
#   'a',
#   'gente',
#   'era',
#   'brother',
#   ',',
#   'uma',
#   'vez',
#   'ele',
#   'me',
#   'ajudou',
#   'a',
#   'comprar',
#   'um',
#   'notebook',
#   'pq',
#   'eu',
#   'nao',
#   'manjava',
#   'kkk',
#   'mas',
#   'era',
#   'fake',
#   'e',
#   'foi',
#   'arrombado',
#   'com',
#   'mulheres'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['e',
#   'eu',
#   'que',
#   'terminei',
#   'o',
#   'trabalho',
#   ',',
#   'na',
#   'hora',
#   'de',
#   'salvar',
#   'meu',
#   'notebook',
#   'desligou',
#   'sozinho'],
#  ['fui',
#   'la',
#   'em',
#   'sao',
#   'pedro',
#   'pega',
#   'o',
#   'notebook',
#   'de',
#   'gk',
#   'pra',
#   'acertar'],
#  ['mexer',
#   'nesse',
#   'notebook',
#   'e',
#   'uma',
#   'merda',
#   'mano',
#   'que',
#   'sdds',
#   'do',
#   'meu',
#   'celular'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['mas',
#   'eh',
#   'obvio',
#   'que',
#   'meu',
#   'notebook',
#   'vai',
#   'atualizar',
#   'justamente',
#   'na',
#   'vespera',
#   'da',
#   'entrega',
#   'do',
#   'projeto'],
#  ['@', 'pimpolhayt', 'quantos', 'gb', 'tem', 'seu', 'notebook', '?'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['quase',
#   'levei',
#   'uma',
#   'queda',
#   'com',
#   'meu',
#   'notebook',
#   'e',
#   'meu',
#   'celular',
#   'na',
#   'mao',
#   '[',
#   '?',
#   ']'],
#  ['dica',
#   'de',
#   'hj',
#   'com',
#   'skala',
#   ':',
#   'verifiquem',
#   'se',
#   'sua',
#   'hidratacao',
#   'pode',
#   'cair',
#   'misteriosamente',
#   'em',
#   'algum',
#   'livro',
#   'ou',
#   'notebook',
#   'antes',
#   'de',
#   'qualquer',
#   'coisa',
#   'taokei',
#   'https',
#   ':',
#   '//t.co/ta1sygt3qj'],
#  ['meu',
#   'notebook',
#   'pipocando',
#   'todo',
#   'so',
#   'pra',
#   'salvar',
#   'um',
#   'mapa',
#   'do',
#   'arcgis',
#   '...',
#   'https',
#   ':',
#   '//t.co/r7n7cwo7wu'],
#  ['meu', 'notebook', 'quebrou', '900', 'reais', 'pra', 'consertar'],
#  ['tenho',
#   'que',
#   'comprar',
#   'os',
#   'negocios',
#   'do',
#   'meu',
#   'rosto',
#   ',',
#   'rezar',
#   'pra',
#   'ganhar',
#   'a',
#   'bolsa',
#   'da',
#   'faculdade',
#   'pra',
#   'tentar',
#   'comprar',
#   'meu',
#   'notebook',
#   '.',
#   'agrrhhh',
#   'queria',
#   'ser',
#   'rica',
#   '[',
#   '?',
#   ']'],
#  ['lesbica*',
#   'kkkkk',
#   'meu',
#   'notebook',
#   'sempre',
#   'corrige',
#   'pro',
#   'plural',
#   '...',
#   'coletividads'],
#  ['toda',
#   'hora',
#   'eu',
#   'levando',
#   'um',
#   'susto',
#   'porque',
#   'a',
#   'hora',
#   'do',
#   'notebook',
#   'ta',
#   'no',
#   'horario',
#   'de',
#   'verao'],
#  ['gostaria', 'tanto', 'q', 'o', 'meu', 'notebook', 'destravasse'],
#  ['mano',
#   'eu',
#   'passei',
#   'um',
#   'tempao',
#   'tentando',
#   'usar',
#   'o',
#   'notebook',
#   'da',
#   'minha',
#   'irma',
#   'e',
#   'o',
#   'bagulho',
#   'nn',
#   'ligou',
#   'agr',
#   'ela',
#   'ta',
#   'de',
#   'boa',
#   'usando',
#   'ele',
#   'aqui'],
#  ['mano',
#   'e',
#   'a',
#   'minha',
#   'sobrinha',
#   'q',
#   'nao',
#   'pode',
#   'ver',
#   'nd',
#   'e',
#   'ja',
#   'acha',
#   'q',
#   'e',
#   'brinquedo',
#   'e',
#   'pede',
#   'p',
#   'comprar',
#   'kkkkkkk',
#   'n',
#   'da',
#   ',',
#   'a',
#   'menina',
#   'viu',
#   'uma',
#   'hemacia',
#   'no',
#   'meu',
#   'notebook',
#   'enquanto',
#   'eu',
#   'estudava',
#   'e',
#   'sismou',
#   'q',
#   'queria',
#   'o',
#   '``',
#   'brinquedo',
#   "''",
#   '[',
#   '?',
#   ']'],
#  ['me',
#   'acostumei',
#   'tanto',
#   'a',
#   'usar',
#   'o',
#   'notebook',
#   'e',
#   'usar',
#   'o',
#   'youtube',
#   'pra',
#   'escutar',
#   'msc',
#   'que',
#   'ja',
#   'consigo',
#   'mexer',
#   'sem',
#   'olhar',
#   'pra',
#   'tela',
#   'kkfjmm'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['uma',
#   'mulher',
#   'com',
#   'notebook',
#   'novo',
#   'nao',
#   'quer',
#   'guerra',
#   'com',
#   'ninguem',
#   ',',
#   'agora',
#   'esse',
#   'tcc',
#   'sai',
#   'hein'],
#  ['comprei',
#   'um',
#   'notebook',
#   'novo',
#   'e',
#   'lembro',
#   'o',
#   'motivo',
#   'de',
#   'nao',
#   'querer',
#   'usar',
#   'windows'],
#  ['n', 'existe', 'nd', 'mais', 'dificil', 'de', 'que', 'comprar', 'notebook'],
#  ['@',
#   'adelli_s',
#   'meu',
#   'guria',
#   ',',
#   'voce',
#   'ta',
#   'bem',
#   '?',
#   'perdeu',
#   'muita',
#   'coisa',
#   'no',
#   'notebook',
#   '?',
#   'meu',
#   'not',
#   'ta',
#   'so',
#   'o',
#   'po',
#   ',',
#   'se',
#   'nao',
#   'emprestava',
#   'pra',
#   'ti'],
#  ['[',
#   '?',
#   ']',
#   '[',
#   '?',
#   ']',
#   'quer',
#   'ganhar',
#   'esse',
#   'valor',
#   'ou',
#   'ate',
#   'mais',
#   'diariamente',
#   'usando',
#   'apenas',
#   'o',
#   'celular',
#   'ou',
#   'notebook',
#   'deixe',
#   'um',
#   'comentario',
#   '.',
#   'https',
#   ':',
#   '//t.co/jprlsgiluo'],
#  ['@', 'byraissa', 'no', 'notebook', 'da', 'faculdade', 'ainda', 'kkkkkkk'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['rt',
#   '@',
#   'm_carpenedo',
#   ':',
#   'um',
#   'erro',
#   'enorme',
#   'em',
#   'apenas',
#   'duas',
#   'palavras',
#   ':',
#   'notebook',
#   'gamer',
#   '.'],
#  ['praticamente',
#   'a',
#   'cena',
#   'de',
#   'the',
#   'notebook',
#   'serio',
#   'nicholas',
#   'sparks',
#   'que',
#   'lute'],
#  ['*carrego',
#   '3',
#   'bones',
#   ',',
#   '4',
#   'jogos',
#   'de',
#   'cartas',
#   ',',
#   '1',
#   'quebra',
#   'cabeca',
#   'de',
#   '500',
#   'pecas',
#   ',',
#   '2',
#   'necessaires',
#   ',',
#   'prancheta',
#   ',',
#   'caneca',
#   ',',
#   'sombrinha',
#   ',',
#   'balas',
#   'e',
#   'notebook',
#   'na',
#   'mochila*',
#   'oswxld',
#   ':',
#   'ce',
#   'carrega',
#   'o',
#   'mundo',
#   'na',
#   'sua',
#   'mochila',
#   'eu',
#   ':',
#   'gosto',
#   'de',
#   'estar',
#   'preparada',
#   'pra',
#   'tudo',
#   'oswxld',
#   ':',
#   'tem',
#   'remedio',
#   '?',
#   'eu',
#   ':',
#   'https',
#   ':',
#   '//t.co/reqfqclrtx'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['@',
#   'fah44115204',
#   '@',
#   'timedaandrea',
#   '@',
#   'elaine_comenta',
#   'no',
#   'pc',
#   'oi',
#   'notebook',
#   'vc',
#   'instala',
#   'o',
#   'gsautoclicker'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['eu',
#   'com',
#   'mil',
#   'coisas',
#   'pra',
#   'fazer',
#   'e',
#   'deixei',
#   'meu',
#   'notebook',
#   'no',
#   'trampo',
#   'feliz',
#   'que',
#   'nao',
#   'vou',
#   'trampar',
#   'agora',
#   'a',
#   'noite',
#   ',',
#   'porem',
#   'triste',
#   'pq',
#   'tudo',
#   'vai',
#   'acumular'],
#  ['rt',
#   '@',
#   'awaeangels',
#   ':',
#   'sempre',
#   'vou',
#   'lembrar',
#   '...',
#   'eu',
#   'correndo',
#   'pela',
#   'casa',
#   'com',
#   'o',
#   'notebook',
#   'na',
#   'mao',
#   'chorando',
#   'mt',
#   'igual',
#   'uma',
#   'doida',
#   'e',
#   'minha',
#   'mae',
#   'perguntando',
#   '``',
#   'ele',
#   '...'],
#  ['@',
#   'janacabral_cute',
#   'fora',
#   'que',
#   'o',
#   'notebook',
#   'ta',
#   'uma',
#   'delicia',
#   'de',
#   'ruim'],
#  ['q',
#   'saco',
#   'mano',
#   'compro',
#   'o',
#   'notebook',
#   'e',
#   'e',
#   'uma',
#   'bosta',
#   ',',
#   'tava',
#   'no',
#   '60',
#   '%',
#   'e',
#   'desligou',
#   'e',
#   'agora',
#   'fala',
#   'q',
#   'tava',
#   'mos',
#   '0',
#   '%'],
#  ['sexta', 'chega', 'meu', 'notebook', 'tbm'],
#  ['baixei',
#   'varios',
#   'livros',
#   'em',
#   'pdf',
#   ',',
#   'hoje',
#   'eu',
#   'viro',
#   'a',
#   'noite',
#   'lendo',
#   'ja',
#   'que',
#   'nao',
#   'tem',
#   '@',
#   'notebook'],
#  ['lembro',
#   'de',
#   'mim',
#   'na',
#   'frente',
#   'do',
#   'notebook',
#   'rosa',
#   'dela',
#   ',',
#   'e',
#   'minha',
#   'mao',
#   'do',
#   'meu',
#   'lado',
#   'no',
#   'sofa',
#   ',',
#   'e',
#   'quando',
#   'abriu',
#   '10',
#   'da',
#   'manha',
#   'eu',
#   'entrei',
#   'ja',
#   'estava',
#   'esgotado',
#   'a',
#   'premium',
#   ',',
#   'eu',
#   'selecionei',
#   'uma',
#   'pista',
#   'normal',
#   'e',
#   'uma',
#   'premium',
#   'e',
#   'apertei',
#   'avancar',
#   ',',
#   'foi',
#   'os',
#   'dois',
#   ',',
#   'depois',
#   'so',
#   'exclui',
#   'a',
#   'pista',
#   'normal',
#   '.',
#   'chorava',
#   'feito',
#   'uma',
#   'louca'],
#  ['meu',
#   'notebook',
#   'e',
#   'nao',
#   'velho',
#   'e',
#   'ruim',
#   'que',
#   'ele',
#   'comeca',
#   'a',
#   'parar',
#   'sozinho',
#   'quando',
#   'fica',
#   'ligado',
#   'muito',
#   'tempo',
#   ',',
#   'eu',
#   'so',
#   'torco',
#   'pra',
#   'ele',
#   'nao',
#   'parar',
#   'de',
#   'vez',
#   'ate',
#   'eu',
#   'me',
#   'formar'],
#  ['crh',
#   'q',
#   'exemplo',
#   '!',
#   'lembro',
#   'de',
#   'qnd',
#   'vendi',
#   'brigadeiro',
#   'pra',
#   'comprar',
#   'meu',
#   'notebook',
#   'https',
#   ':',
#   '//t.co/hrwhl3lczm'],
#  ['hoje',
#   'a',
#   'mulher',
#   'chegou',
#   'com',
#   'um',
#   'notebook',
#   'da',
#   'acer',
#   'pedindo',
#   'ajuda',
#   'porque',
#   'nao',
#   'tava',
#   'ligando',
#   'eu',
#   'trabalho',
#   'com',
#   'o',
#   'suporte',
#   'da',
#   '...',
#   'dell'],
#  ['rt',
#   '@',
#   'borelanjo',
#   ':',
#   'stickers',
#   'pra',
#   'customizar',
#   'o',
#   'notebook',
#   '#',
#   'ubuntu',
#   '#',
#   'linux',
#   'https',
#   ':',
#   '//t.co/s5ucdks3au'],
#  ['rt',
#   '@',
#   'bullshhhit',
#   ':',
#   'mexer',
#   'no',
#   'notebook',
#   'dentro',
#   'de',
#   'casa',
#   'com',
#   'uma',
#   'arma',
#   'do',
#   'lado',
#   'e',
#   'o',
#   'maior',
#   'conceito',
#   'de',
#   'micropenis',
#   'ja',
#   'visto',
#   'https',
#   ':',
#   '//t.co/fphq0lvnv4'],
#  ['pqp',
#   'meu',
#   'notebook',
#   'ta',
#   'um',
#   'caos',
#   'de',
#   'lento',
#   'alguem',
#   'pra',
#   'formatar'],
#  ['@',
#   'babisu_',
#   'ta',
#   'dificil',
#   'jogar',
#   'lol',
#   'no',
#   'meu',
#   'notebook',
#   'toda',
#   'hora',
#   'dropa',
#   'mt',
#   'o',
#   'fps',
#   ',',
#   'tem',
#   'vezes',
#   'que',
#   'trava',
#   'por',
#   'completo',
#   'e',
#   'dps',
#   'volta',
#   'e',
#   'comum',
#   'ter',
#   'do',
#   'nada',
#   '5',
#   'de',
#   'fps'],
#  ['@',
#   'mcsardas',
#   'hahahaha',
#   'eu',
#   'no',
#   'maximo',
#   'consigo',
#   'um',
#   'notebook',
#   'com',
#   'duas',
#   'abas',
#   'e',
#   'celular',
#   'com',
#   'duas',
#   'abas',
#   'tambem',
#   'kkkkk'],
#  ['@', 'gloriastefanyte', 'me', 'manda', 'um', 'notebook'],
#  ['@', 'allananerii', 'notebook', 'eu', 'acho', 'melhor', 'more'],
#  ['eu',
#   'aqui',
#   'no',
#   'notebook',
#   'e',
#   'meu',
#   'irmao',
#   'vendo',
#   'foto',
#   'de',
#   'mulher',
#   'pelada',
#   'no',
#   'celular',
#   ',',
#   'acho',
#   'que',
#   'ele',
#   'nao',
#   'percebeu',
#   'que',
#   'eu',
#   'to',
#   'so',
#   'observandokkkkkkkk'],
#  ['da',
#   'um',
#   'medo',
#   'em',
#   'deixar',
#   'meu',
#   'celular',
#   'com',
#   'o',
#   'guilherme',
#   'porque',
#   'se',
#   'meus',
#   'pais',
#   'pegarem',
#   'eu',
#   'me',
#   'considero',
#   'morta'],
#  ['qual',
#   'fita',
#   'que',
#   'pagaram',
#   'meu',
#   'celular',
#   'e',
#   'escreveram',
#   'altas',
#   'paradas',
#   'no',
#   'tt'],
#  ['@',
#   'thegreatestpj',
#   'okay',
#   ',',
#   'eu',
#   'vou',
#   'ficar',
#   'quietinha',
#   ',',
#   'mas',
#   'eu',
#   'nao',
#   'vou',
#   'te',
#   'largar',
#   '.',
#   'prepare',
#   'o',
#   'fone',
#   'de',
#   'ouvido',
#   ',',
#   'eu',
#   'vou',
#   'me',
#   'trocar',
#   'por',
#   'que',
#   'nao',
#   'posso',
#   'entrar',
#   'sanguenta',
#   'e',
#   'vou',
#   'ficar',
#   'ai',
#   'do',
#   'seu',
#   'lado',
#   'com',
#   'a',
#   'discografia',
#   'de',
#   'beatles',
#   'no',
#   'meu',
#   'celular',
#   '.'],
#  ['fico', 'nessa', 'bosta', 'de', 'celular'],
#  ['rt',
#   '@',
#   'hstyiesoul',
#   ':',
#   'mae',
#   ':',
#   'filho',
#   ',',
#   'o',
#   'que',
#   'e',
#   'esse',
#   'negocio',
#   'laranja',
#   'que',
#   'vc',
#   'tanto',
#   'mexe',
#   'nesse',
#   'celular',
#   '?',
#   'eu',
#   'saindo',
#   'do',
#   'wattpad',
#   'olhando',
#   'pra',
#   'ela',
#   ':',
#   'https',
#   ':',
#   '//',
#   '...'],
#  ['na',
#   'minha',
#   'epoca',
#   'nao',
#   'podia',
#   'nem',
#   'levar',
#   'o',
#   'celular',
#   'pra',
#   'escola',
#   'https',
#   ':',
#   '//t.co/bbubwv1qhs'],
#  ['rt',
#   '@',
#   'antoniamallet',
#   ':',
#   'depois',
#   'que',
#   'a',
#   'gente',
#   'vira',
#   'mae',
#   'o',
#   'celular',
#   'so',
#   'tem',
#   'foto',
#   'do',
#   'filho'],
#  ['rt',
#   '@',
#   'chelezinha',
#   ':',
#   '@',
#   'millenast7',
#   'a',
#   'falta',
#   'do',
#   'celular',
#   'ta',
#   'te',
#   'deixando',
#   'assim',
#   'kkk'],
#  ['@',
#   'trl_azp',
#   'pensei',
#   'que',
#   'fosse',
#   'meu',
#   'celular',
#   'bugando',
#   ',',
#   'mas',
#   'ainda',
#   'bem',
#   'que',
#   'nao',
#   'e'],
#  ['e',
#   'a',
#   'quarta',
#   'vez',
#   'no',
#   'dia',
#   'que',
#   'eu',
#   'carrego',
#   'meu',
#   'celular',
#   ',',
#   'devo',
#   'me',
#   'preocupar',
#   '?',
#   'https',
#   ':',
#   '//t.co/fvwsmhsasc'],
#  ['os',
#   'meninos',
#   'me',
#   'gastando',
#   'so',
#   'porque',
#   'o',
#   'fone',
#   'funcionou',
#   'no',
#   'celular',
#   'de',
#   'geral',
#   'e',
#   'no',
#   'meu',
#   'nao',
#   ',',
#   'falaram',
#   'ate',
#   'que',
#   'meu',
#   'celular',
#   'e',
#   'falsificado',
#   ',',
#   've',
#   'se',
#   'pode',
#   '.',
#   'kkkkkkkkkkkkk'],
#  ['abro',
#   'a',
#   'camera',
#   'do',
#   'celular',
#   'e',
#   'autoestima',
#   'so',
#   'desce',
#   'pqp'],
#  ['rt',
#   '@',
#   'destacou',
#   ':',
#   '-',
#   'n',
#   'fica',
#   'brava',
#   'com',
#   'isso',
#   'n',
#   'rlx',
#   'eu',
#   'no',
#   'whatsapp',
#   ':',
#   'pode',
#   'deixar',
#   'kkkkjj',
#   'eu',
#   'por',
#   'tras',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/lpvgq9ywus'],
#  ['odeio',
#   'que',
#   'toquem',
#   'no',
#   'meu',
#   'celular',
#   ',',
#   'acho',
#   'a',
#   'morte',
#   'https',
#   ':',
#   '//t.co/y5nbpvir7d'],
#  ['estou', 'sem', 'celular', ',', 'fe'],
#  ['minha',
#   'queda',
#   'por',
#   'voce',
#   'pode',
#   'ate',
#   'ser',
#   'grande',
#   '!',
#   'mais',
#   'vc',
#   'ja',
#   'viu',
#   'quantas',
#   'quedas',
#   'meu',
#   'celular',
#   'dar',
#   'por',
#   'dia',
#   'no',
#   'chao',
#   '?'],
#  ['rt',
#   '@',
#   'hstyiesoul',
#   ':',
#   'mae',
#   ':',
#   'filho',
#   ',',
#   'o',
#   'que',
#   'e',
#   'esse',
#   'negocio',
#   'laranja',
#   'que',
#   'vc',
#   'tanto',
#   'mexe',
#   'nesse',
#   'celular',
#   '?',
#   'eu',
#   'saindo',
#   'do',
#   'wattpad',
#   'olhando',
#   'pra',
#   'ela',
#   ':',
#   'https',
#   ':',
#   '//',
#   '...'],
#  ['o',
#   'roubo',
#   'do',
#   'celular',
#   ':',
#   'imprevistos',
#   'acontecem',
#   'de',
#   'qualquer',
#   'jeito',
#   'e',
#   'o',
#   'mundo',
#   'infelizmente',
#   'nao',
#   'gira',
#   'em',
#   'torno',
#   'dos',
#   'nossos',
#   'planos',
#   ':',
#   '~~'],
#  ['@',
#   'eviih_martiins',
#   'o',
#   'celular',
#   'ja',
#   'caiu',
#   'na',
#   'minha',
#   'cara',
#   'duas',
#   'vezes',
#   'kkkkkkkkkkkkkkk'],
#  ['rt',
#   '@',
#   're_apeixoto',
#   ':',
#   'qual',
#   'o',
#   'seu',
#   'egoismo',
#   'mais',
#   'idiota',
#   '?',
#   'o',
#   'meu',
#   'e',
#   'odiar',
#   'emprestar',
#   'carregador',
#   'de',
#   'celular',
#   '.'],
#  ['nao',
#   'acredito',
#   'que',
#   'vou',
#   'ter',
#   'que',
#   'formatar',
#   'esse',
#   'celular',
#   'de',
#   'novo',
#   'jesus',
#   'me',
#   'leva',
#   'por',
#   'favor'],
#  ['rt',
#   '@',
#   'mariactomain',
#   ':',
#   'odeio',
#   'que',
#   'ficam',
#   'olhando',
#   'quando',
#   'to',
#   'mexendo',
#   'no',
#   'celular',
#   ',',
#   'isso',
#   'me',
#   'mata'],
#  ['rt',
#   '@',
#   'otempo',
#   ':',
#   'o',
#   'mineirao',
#   'ate',
#   'balancou',
#   '!',
#   'massa',
#   'do',
#   '#',
#   'galo',
#   'canta',
#   'o',
#   'hino',
#   'com',
#   'toda',
#   'a',
#   'forca',
#   'dos',
#   'pulmoes',
#   '.',
#   'bonita',
#   'festa',
#   'que',
#   'ate',
#   'estourou',
#   'o',
#   'audio',
#   'do',
#   'cel',
#   '...'],
#  ['eu',
#   'sinto',
#   'falta',
#   'da',
#   'minha',
#   'familia',
#   ',',
#   'e',
#   'to',
#   'tentando',
#   'voltar',
#   'a',
#   'interagir',
#   'com',
#   'eles',
#   'como',
#   'antes',
#   ',',
#   'mas',
#   'nao',
#   'da',
#   'ne',
#   ',',
#   'minha',
#   'obrigacao',
#   'nao',
#   'e',
#   'eles',
#   'nem',
#   'meus',
#   'estudos',
#   ',',
#   'e',
#   'passar',
#   'o',
#   'dia',
#   'inteiro',
#   'com',
#   'a',
#   'cara',
#   'grudada',
#   'no',
#   'celular'],
#  ['essa',
#   'pretensa',
#   'autoridade',
#   'moral',
#   'do',
#   'cancelador',
#   'nao',
#   'e',
#   'quase',
#   'nada',
#   'diferente',
#   'da',
#   'de',
#   'nego',
#   'que',
#   'amarra',
#   'ladrao',
#   'de',
#   'celular',
#   'no',
#   'poste',
#   '.',
#   'o',
#   'sentimento',
#   'de',
#   'pertencimento',
#   'ao',
#   'grupo',
#   'dos',
#   'justos',
#   'e',
#   'o',
#   'mesmo'],
#  ['gays',
#   'mas',
#   'me',
#   'ajudem',
#   'aqui',
#   ',',
#   'eu',
#   'compro',
#   'o',
#   'dvd',
#   'da',
#   'speak',
#   'yourself',
#   'ou',
#   'guardo',
#   'o',
#   'dinheiro',
#   'pra',
#   'comprar',
#   'meu',
#   'celular',
#   'novo',
#   '?',
#   '?',
#   '?',
#   'ta',
#   'tipo',
#   '349,99',
#   'com',
#   'frete',
#   'incluso',
#   'onde',
#   'eu',
#   'vou',
#   'comprar',
#   'o',
#   'dvd'],
#  ['rt',
#   '@',
#   'lulurras',
#   ':',
#   '``',
#   'tu',
#   'eh',
#   'minha',
#   'po',
#   "''",
#   'kkkkkk',
#   'eu',
#   'do',
#   'outro',
#   'lado',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/fosf3uby3p'],
#  ['@',
#   'jaosadviado',
#   'sim',
#   ',',
#   'tem',
#   '10',
#   'anos',
#   'celular',
#   'mais',
#   'velho',
#   'q',
#   'voce'],
#  ['@',
#   'czrfahd',
#   'nao',
#   'compra',
#   'do',
#   'paraguai',
#   ',',
#   'vai',
#   'fuder',
#   'sua',
#   'bateria',
#   'e',
#   'consequentemente',
#   'o',
#   'celular'],
#  ['meu', 'celular', 'vai', 'desligar', 'e', 'to', 'sem', 'carregador'],
#  ['quando',
#   'a',
#   'pessoa',
#   'nao',
#   'sustenta',
#   'o',
#   'que',
#   'faz',
#   'e',
#   'assim',
#   ',',
#   'nao',
#   'pode',
#   'ver',
#   'nada',
#   'que',
#   'quebra',
#   'o',
#   'celular',
#   'da',
#   'pessoa',
#   'mastiga',
#   'e',
#   'engole',
#   'caladinho',
#   'bebe'],
#  ['rt',
#   '@',
#   'hstyiesoul',
#   ':',
#   'mae',
#   ':',
#   'filho',
#   ',',
#   'o',
#   'que',
#   'e',
#   'esse',
#   'negocio',
#   'laranja',
#   'que',
#   'vc',
#   'tanto',
#   'mexe',
#   'nesse',
#   'celular',
#   '?',
#   'eu',
#   'saindo',
#   'do',
#   'wattpad',
#   'olhando',
#   'pra',
#   'ela',
#   ':',
#   'https',
#   ':',
#   '//',
#   '...'],
#  ['meu', 'celular', 'ta', 'travando', 'tanto'],
#  ['comprei',
#   'uma',
#   'pelicula',
#   'e',
#   'uma',
#   'capinha',
#   'nova',
#   ',',
#   'parece',
#   'que',
#   'eu',
#   'comprei',
#   'um',
#   'celular',
#   'novo'],
#  ['@', 'rronyvieira', 'celular', 'bosta', 'igual', 'a', 'vc'],
#  ['bibi',
#   'minha',
#   'bicicleta',
#   'bebi',
#   'minha',
#   'tv',
#   'so',
#   'nao',
#   'bebo',
#   'o',
#   'meu',
#   'celular',
#   'pq',
#   'eu',
#   'preciso',
#   'ligar',
#   'pra',
#   'voce'],
#  ['vou',
#   'ter',
#   'que',
#   'levar',
#   'essa',
#   'porra',
#   'de',
#   'celular',
#   'na',
#   'autorizada'],
#  ['rt',
#   '@',
#   're_apeixoto',
#   ':',
#   'qual',
#   'o',
#   'seu',
#   'egoismo',
#   'mais',
#   'idiota',
#   '?',
#   'o',
#   'meu',
#   'e',
#   'odiar',
#   'emprestar',
#   'carregador',
#   'de',
#   'celular',
#   '.'],
#  ['celular', 'da', 'minha', 'mae', 'ta', 'uma', 'merda'],
#  ['estou',
#   'querendo',
#   'trocar',
#   'a',
#   'tela',
#   'do',
#   'meu',
#   'celular',
#   ',',
#   'mais',
#   'ficar',
#   'sem',
#   'celular',
#   'e',
#   'foda',
#   'dms',
#   ',',
#   'deus',
#   'me',
#   'livre'],
#  ['e',
#   'eu',
#   'q',
#   'reduzi',
#   'minha',
#   'conta',
#   'de',
#   'celular',
#   'em',
#   '98',
#   'reais',
#   'e',
#   'ganhei',
#   'mais',
#   '9gb',
#   'de',
#   'internet'],
#  ['rt',
#   '@',
#   'fineriine',
#   ':',
#   'quando',
#   'pedem',
#   'meu',
#   'celular',
#   'p',
#   'ver',
#   'uma',
#   'foto',
#   'e',
#   'ela',
#   'comeca',
#   'a',
#   'arrasta',
#   'pro',
#   'lado',
#   'https',
#   ':',
#   '//t.co/aaqwmslw5m'],
#  ['rt',
#   '@',
#   'a_belaaa',
#   ':',
#   'vc',
#   'atrai',
#   'oque',
#   'fala',
#   'emprego',
#   'felicidade',
#   'dinheiro',
#   'celular',
#   'novo',
#   'casa',
#   'propria',
#   'moto',
#   'https',
#   ':',
#   '//t.co/riakckrivb'],
#  ['rt',
#   '@',
#   'paulorriq',
#   ':',
#   'eu',
#   'odeio',
#   'ligacao',
#   'entao',
#   'se',
#   'um',
#   'dia',
#   'eu',
#   'te',
#   'ligar',
#   'atende',
#   'a',
#   'porra',
#   'do',
#   'celular',
#   'pq',
#   'e',
#   'algo',
#   'muito',
#   'importante'],
#  ['rt',
#   '@',
#   'destacou',
#   ':',
#   '-',
#   'n',
#   'fica',
#   'brava',
#   'com',
#   'isso',
#   'n',
#   'rlx',
#   'eu',
#   'no',
#   'whatsapp',
#   ':',
#   'pode',
#   'deixar',
#   'kkkkjj',
#   'eu',
#   'por',
#   'tras',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/lpvgq9ywus'],
#  ['eu',
#   'preparada',
#   'p',
#   'largar',
#   'do',
#   'celular',
#   'e',
#   'ir',
#   'dormir',
#   ',',
#   'vem',
#   'a',
#   'peste',
#   'da',
#   'mayara',
#   'e',
#   'erika',
#   'perturbar',
#   'pra',
#   'sairmos',
#   'sexta'],
#  ['rt',
#   '@',
#   'lulurras',
#   ':',
#   '``',
#   'tu',
#   'eh',
#   'minha',
#   'po',
#   "''",
#   'kkkkkk',
#   'eu',
#   'do',
#   'outro',
#   'lado',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/fosf3uby3p'],
#  ['quem',
#   'nunca',
#   '?',
#   'entra',
#   'no',
#   'banheiro',
#   'para',
#   'tomar',
#   'banho',
#   ',',
#   'senta',
#   'no',
#   'vaso',
#   'a',
#   'pessoa',
#   'nem',
#   'vai',
#   'cagar',
#   'esquece',
#   'da',
#   'vida',
#   'e',
#   'fica',
#   'mexendo',
#   'no',
#   'celular',
#   ',',
#   'pqp',
#   'nojento',
#   'mais',
#   'e',
#   'a',
#   'realidade',
#   '.'],
#  ['amanha',
#   'vou',
#   'me',
#   'apossar',
#   'um',
#   'pouquinho',
#   'do',
#   'celular',
#   'da',
#   'maira',
#   'se',
#   'ela',
#   'deixar',
#   ',',
#   'preciso',
#   'de',
#   'fotos',
#   'novas'],
#  ['confundem', 'celular', 'com', 'uma', 'glock'],
#  ['rt',
#   '@',
#   'daibego',
#   ':',
#   'minha',
#   'bateria',
#   'do',
#   'celular',
#   'esta',
#   '49',
#   '%',
#   '...',
#   'e',
#   'a',
#   'de',
#   'vcs',
#   '?',
#   'https',
#   ':',
#   '//t.co/tacas0refw'],
#  ['rt',
#   '@',
#   'urreasflower',
#   ':',
#   'sequestrador',
#   ':',
#   'pegamos',
#   'sua',
#   'namorada',
#   'bailey',
#   ':',
#   'eu',
#   'nao',
#   'tenho',
#   'namorada',
#   'sequestrador',
#   ':',
#   'entao',
#   'quem',
#   'ta',
#   'falando',
#   '``',
#   'ew',
#   "''",
#   'pra',
#   'tudo',
#   '?',
#   '?',
#   '?',
#   '?',
#   '...'],
#  ['vivo',
#   'mudando',
#   'de',
#   'numero',
#   ',',
#   'de',
#   'twitter',
#   'ate',
#   'de',
#   'celular'],
#  ['o',
#   'ultimo',
#   'backup',
#   'q',
#   'meu',
#   'celular',
#   'encontrou',
#   'foi',
#   'em',
#   '18',
#   'd',
#   'outubro',
#   'e',
#   'meus',
#   'ctt',
#   'tao',
#   'sem',
#   'nome',
#   'kjkkkkkkk'],
#  ['se',
#   'fizessem',
#   'isso',
#   'cmg',
#   'ia',
#   'acabar',
#   'com',
#   'a',
#   'memoria',
#   'do',
#   'celular',
#   'eu',
#   'sei',
#   'que',
#   'e',
#   'errado',
#   ',',
#   'mas',
#   'e',
#   'um',
#   'vicio',
#   'fazer',
#   'oq',
#   'ne',
#   'https',
#   ':',
#   '//t.co/lt2qbksrsb'],
#  ['linda',
#   'a',
#   'segunda',
#   'foto',
#   'tirada',
#   'pelo',
#   'meu',
#   'celular',
#   'https',
#   ':',
#   '//t.co/kq5ed2vwpn'],
#  ['rt',
#   '@',
#   'otempo',
#   ':',
#   'o',
#   'mineirao',
#   'ate',
#   'balancou',
#   '!',
#   'massa',
#   'do',
#   '#',
#   'galo',
#   'canta',
#   'o',
#   'hino',
#   'com',
#   'toda',
#   'a',
#   'forca',
#   'dos',
#   'pulmoes',
#   '.',
#   'bonita',
#   'festa',
#   'que',
#   'ate',
#   'estourou',
#   'o',
#   'audio',
#   'do',
#   'cel',
#   '...'],
#  ['rt',
#   '@',
#   'citeimusicao',
#   ':',
#   'meu',
#   'coracao',
#   'sempre',
#   'foi',
#   'seu',
#   ',',
#   'so',
#   'seu',
#   ',',
#   'de',
#   'mais',
#   'ninguem',
#   ',',
#   'papo',
#   'no',
#   'bar',
#   ',',
#   'no',
#   'celular',
#   ',',
#   'amigos',
#   'todo',
#   'mundo',
#   'tem',
#   ',',
#   'pra',
#   'que',
#   'brigar',
#   '?',
#   'desc',
#   '...'],
#  ['rt',
#   '@',
#   'otempo',
#   ':',
#   'o',
#   'mineirao',
#   'ate',
#   'balancou',
#   '!',
#   'massa',
#   'do',
#   '#',
#   'galo',
#   'canta',
#   'o',
#   'hino',
#   'com',
#   'toda',
#   'a',
#   'forca',
#   'dos',
#   'pulmoes',
#   '.',
#   'bonita',
#   'festa',
#   'que',
#   'ate',
#   'estourou',
#   'o',
#   'audio',
#   'do',
#   'cel',
#   '...'],
#  ['quero', 'outro', 'celular'],
#  ['boa',
#   'noite',
#   'pra',
#   'quem',
#   'quebrou',
#   'a',
#   'tela',
#   'do',
#   'celular',
#   'pela',
#   'segunda',
#   'vez'],
#  ['deixei',
#   'cair',
#   'tinta',
#   'no',
#   'celular',
#   'vai',
#   'ficar',
#   'rosa',
#   'foda',
#   'se'],
#  ['rt',
#   '@',
#   'oficialhenny',
#   ':',
#   'fui',
#   'apaga',
#   'nossas',
#   'conversa',
#   ',',
#   'o',
#   'celular',
#   'ate',
#   'travou',
#   'de',
#   'tanta',
#   'mentira',
#   'que',
#   'vc',
#   'fala'],
#  ['meu',
#   'deus',
#   'meu',
#   'celular',
#   'nao',
#   'quer',
#   'carregar',
#   'eu',
#   'nao',
#   'aguento',
#   'maaaaaaaaaaaaaaaaaaaaaais',
#   'https',
#   ':',
#   '//t.co/4ojao2qyjb'],
#  ['e',
#   'ainda',
#   'em',
#   'outro',
#   'dia',
#   'o',
#   'celular',
#   'da',
#   'amg',
#   'dela',
#   'tava',
#   'quente',
#   '(',
#   'de',
#   'tanto',
#   'usar',
#   ')',
#   ',',
#   'ai',
#   'ela',
#   'disse',
#   'bem',
#   'assim',
#   'pra',
#   'amg',
#   '``',
#   'isso',
#   'nao',
#   'presta',
#   'nao',
#   ',',
#   'vai',
#   'explodir',
#   "''",
#   'e',
#   'entao',
#   'a',
#   'amg',
#   'jogou',
#   'o',
#   'celular',
#   'no',
#   'lixo',
#   'kkkkkkkkkk'],
#  ['rt',
#   '@',
#   'idash404',
#   ':',
#   '@',
#   'schafferjp',
#   '@',
#   'juniorf171',
#   'o',
#   'amigo',
#   'ja',
#   'puxando',
#   'a',
#   'tela',
#   'do',
#   'celular'],
#  ['as',
#   'vezes',
#   'parece',
#   'q',
#   'o',
#   'celular',
#   'se',
#   'joga',
#   'da',
#   'minha',
#   'mao',
#   'e',
#   'diz',
#   'tchaaaaau',
#   'pq',
#   'vai',
#   'escorregando',
#   'qt',
#   'mais',
#   'eu',
#   'tento',
#   'pegar',
#   'mais',
#   'ele',
#   'escorrega',
#   'e',
#   'o',
#   'estouro',
#   'eh',
#   'pior',
#   'do',
#   'q',
#   'seria',
#   'se',
#   'eu',
#   'n',
#   'tivesse',
#   'tentado',
#   'pegar'],
#  ['n',
#   'sei',
#   'pq',
#   'n',
#   'fui',
#   'pra',
#   'cg',
#   'agr',
#   'vou',
#   'ficar',
#   'la',
#   'no',
#   'meu',
#   'pai',
#   'entediada',
#   'sem',
#   'celular'],
#  ['@',
#   'qiansiut',
#   'tenta',
#   'fazer',
#   'o',
#   'seu',
#   'trabalho',
#   'pelo',
#   'celular',
#   'bb'],
#  ['rt',
#   '@',
#   'destacou',
#   ':',
#   '-',
#   'n',
#   'fica',
#   'brava',
#   'com',
#   'isso',
#   'n',
#   'rlx',
#   'eu',
#   'no',
#   'whatsapp',
#   ':',
#   'pode',
#   'deixar',
#   'kkkkjj',
#   'eu',
#   'por',
#   'tras',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/lpvgq9ywus'],
#  ['toda',
#   'timidez',
#   'dentro',
#   'do',
#   'quarto',
#   'some',
#   'tudo',
#   'e',
#   'permitido',
#   'entre',
#   'a',
#   'mulher',
#   'e',
#   'homem',
#   'eu',
#   ',',
#   'voce',
#   'e',
#   'o',
#   'celular'],
#  ['rt',
#   '@',
#   're_apeixoto',
#   ':',
#   'qual',
#   'o',
#   'seu',
#   'egoismo',
#   'mais',
#   'idiota',
#   '?',
#   'o',
#   'meu',
#   'e',
#   'odiar',
#   'emprestar',
#   'carregador',
#   'de',
#   'celular',
#   '.'],
#  ['rt',
#   '@',
#   'jorgeviddal',
#   ':',
#   'vo',
#   'baixar',
#   'tinder',
#   'no',
#   'celular',
#   'do',
#   'meu',
#   'pai',
#   'fodase'],
#  ['@',
#   'lari_samaria',
#   'voto',
#   'em',
#   'luana',
#   'deixar',
#   'o',
#   'celular',
#   'filmando'],
#  ['rt',
#   '@',
#   'otempo',
#   ':',
#   'o',
#   'mineirao',
#   'ate',
#   'balancou',
#   '!',
#   'massa',
#   'do',
#   '#',
#   'galo',
#   'canta',
#   'o',
#   'hino',
#   'com',
#   'toda',
#   'a',
#   'forca',
#   'dos',
#   'pulmoes',
#   '.',
#   'bonita',
#   'festa',
#   'que',
#   'ate',
#   'estourou',
#   'o',
#   'audio',
#   'do',
#   'cel',
#   '...'],
#  ['rt',
#   '@',
#   'wefightt',
#   ':',
#   'voces',
#   'que',
#   'estao',
#   'tendo',
#   'problemas',
#   'pra',
#   'logar',
#   'no',
#   'site',
#   'do',
#   'mama',
#   'pelo',
#   'celular',
#   ',',
#   'experimentem',
#   'colocar',
#   'o',
#   'navegador',
#   'em',
#   'modo',
#   'desktop',
#   '(',
#   'ver',
#   '...'],
#  ['rt',
#   '@',
#   'lulurras',
#   ':',
#   '``',
#   'tu',
#   'eh',
#   'minha',
#   'po',
#   "''",
#   'kkkkkk',
#   'eu',
#   'do',
#   'outro',
#   'lado',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/fosf3uby3p'],
#  ['rt',
#   '@',
#   'trouxavcs',
#   ':',
#   'ei',
#   'vc',
#   'vc',
#   'ai',
#   'com',
#   'o',
#   'celular',
#   'na',
#   'mao',
#   'e',
#   'vc',
#   'mesmo',
#   'c',
#   'ta',
#   'mo',
#   'triste',
#   'por',
#   'dentro',
#   'ne',
#   '?'],
#  ['226',
#   '*',
#   '>',
#   'voce',
#   'ta',
#   'afim',
#   'dele',
#   ',',
#   'tony',
#   '?',
#   'celular',
#   'do',
#   'tony',
#   'https',
#   ':',
#   '//t.co/khb7tdyghg'],
#  ['@',
#   'schafferjp',
#   '@',
#   'juniorf171',
#   'o',
#   'amigo',
#   'ja',
#   'puxando',
#   'a',
#   'tela',
#   'do',
#   'celular'],
#  ['o',
#   'apple',
#   'watch',
#   'decidiu',
#   'conectar',
#   'no',
#   'meu',
#   'celular',
#   'essa',
#   'humilhada',
#   'aqui',
#   'foi',
#   'exaltada',
#   'mas',
#   'ainda',
#   'nao',
#   'faz',
#   'a',
#   'menor',
#   'ideia',
#   'de',
#   'como',
#   'se',
#   'mexe',
#   'nesse',
#   'troco'],
#  ['so', 'um', 'celular', 'novo', 'na', 'minha', 'vida'],
#  ['gente',
#   ',',
#   'queira',
#   'saber',
#   'o',
#   'que',
#   'ela',
#   'viu',
#   'o',
#   'no',
#   'meu',
#   'celular',
#   'pra',
#   'ficar',
#   'doida'],
#  ['alem',
#   'de',
#   'eu',
#   'ficar',
#   'sem',
#   'celular',
#   'tambem',
#   'to',
#   'sem',
#   'internet',
#   'que',
#   'lindo',
#   'a',
#   'vida',
#   'realmente',
#   'me',
#   'odeia'],
#  ['ficar', 'sem', 'celular', 'e', 'mt', 'ruiim'],
#  ['isso',
#   'q',
#   'esquerda',
#   'quer',
#   'deixar',
#   'o',
#   'povo',
#   'sem',
#   'noticia',
#   'sem',
#   'celular',
#   'sem',
#   'informacao',
#   'https',
#   ':',
#   '//t.co/6zsn3t85sv'],
#  ['@',
#   'raphacarvv',
#   'caralho',
#   'amiga',
#   'pior',
#   'q',
#   'eu',
#   'vi',
#   'q',
#   'alguem',
#   'tinha',
#   'visualizado',
#   'eu',
#   'pensei',
#   'caralho',
#   'sera',
#   'q',
#   'o',
#   'igor',
#   'tava',
#   'no',
#   'meu',
#   'celular',
#   'e',
#   'clicou',
#   '?'],
#  ['rt',
#   '@',
#   'otempo',
#   ':',
#   'o',
#   'mineirao',
#   'ate',
#   'balancou',
#   '!',
#   'massa',
#   'do',
#   '#',
#   'galo',
#   'canta',
#   'o',
#   'hino',
#   'com',
#   'toda',
#   'a',
#   'forca',
#   'dos',
#   'pulmoes',
#   '.',
#   'bonita',
#   'festa',
#   'que',
#   'ate',
#   'estourou',
#   'o',
#   'audio',
#   'do',
#   'cel',
#   '...'],
#  ['@',
#   'fernandakaiser',
#   '@',
#   'cavalcantnanda',
#   'af',
#   'maria',
#   'pq',
#   'nao',
#   'pediu',
#   'quando',
#   'meu',
#   'celular',
#   'estava',
#   'vivo',
#   'eu',
#   'tinha'],
#  ['vo', 'baixar', 'tinder', 'no', 'celular', 'do', 'meu', 'pai', 'fodase'],
#  ['mano',
#   ',',
#   'meu',
#   'pai',
#   'ta',
#   'aprendendo',
#   'a',
#   'mexer',
#   'no',
#   'celular',
#   'e',
#   'ta',
#   'postando',
#   'cada',
#   'coisa'],
#  ['eu',
#   'nao',
#   'posso',
#   'baixar',
#   'jogo',
#   'no',
#   'meu',
#   'celular',
#   'que',
#   'eu',
#   'fico',
#   'viciando',
#   'em',
#   'absolutamente',
#   'todos',
#   '.',
#   'ai',
#   'pareco',
#   'essas',
#   '``',
#   'criancas',
#   "''",
#   'modernas',
#   'que',
#   'so',
#   'param',
#   'de',
#   'fazer',
#   'birra',
#   'quando',
#   'os',
#   'pais',
#   'dao',
#   'o',
#   'tablet',
#   'e',
#   'ficando',
#   'o',
#   'dia',
#   'todo',
#   'jogando',
#   'nessa',
#   'merda',
#   '.'],
#  ['formatando', 'meu', 'celular', 'na', 'forca', 'do', 'odio'],
#  ['rt',
#   '@',
#   're_apeixoto',
#   ':',
#   'qual',
#   'o',
#   'seu',
#   'egoismo',
#   'mais',
#   'idiota',
#   '?',
#   'o',
#   'meu',
#   'e',
#   'odiar',
#   'emprestar',
#   'carregador',
#   'de',
#   'celular',
#   '.'],
#  ['na',
#   'porra',
#   'do',
#   'celular',
#   'nem',
#   'adianta',
#   'jogar',
#   'pq',
#   'vai',
#   'fuder',
#   'ele',
#   'mais',
#   'ainda',
#   ',',
#   'e',
#   'o',
#   'notebook',
#   'nao',
#   'aguenta',
#   'nem',
#   'rodar',
#   '50',
#   'de',
#   'fps'],
#  ['rt',
#   '@',
#   're_apeixoto',
#   ':',
#   'qual',
#   'o',
#   'seu',
#   'egoismo',
#   'mais',
#   'idiota',
#   '?',
#   'o',
#   'meu',
#   'e',
#   'odiar',
#   'emprestar',
#   'carregador',
#   'de',
#   'celular',
#   '.'],
#  ['meu',
#   'celular',
#   'ta',
#   'um',
#   'lixo',
#   'e',
#   'eu',
#   'amo',
#   'o',
#   'conceito',
#   'do',
#   'meu',
#   'pai',
#   'de',
#   'que',
#   'se',
#   'o',
#   'celular',
#   'ta',
#   'ligando',
#   'nao',
#   'tem',
#   'pq',
#   'comprar',
#   'outro',
#   ':',
#   ')'],
#  ['rt',
#   '@',
#   'trouxavcs',
#   ':',
#   'mexer',
#   'no',
#   'celular',
#   'pra',
#   'disfarcar',
#   'a',
#   'timidez',
#   'e',
#   'tao',
#   'eu'],
#  ['sem', 'celular', 'e', 'morte', 'lenta'],
#  ['rt',
#   '@',
#   'destacou',
#   ':',
#   '-',
#   'n',
#   'fica',
#   'brava',
#   'com',
#   'isso',
#   'n',
#   'rlx',
#   'eu',
#   'no',
#   'whatsapp',
#   ':',
#   'pode',
#   'deixar',
#   'kkkkjj',
#   'eu',
#   'por',
#   'tras',
#   'do',
#   'celular',
#   ':',
#   'https',
#   ':',
#   '//t.co/lpvgq9ywus'],
#  ['abro',
#   'a',
#   'camera',
#   'do',
#   'celular',
#   'e',
#   'autoestima',
#   'so',
#   'desce',
#   'pqp'],
#  ['rt',
#   '@',
#   'astronomiaum',
#   ':',
#   'planicies',
#   'marcianas',
#   'registradas',
#   'pela',
#   'camera',
#   'do',
#   'rover',
#   'curiosity',
#   '.',
#   'incrivel',
#   '!',
#   'https',
#   ':',
#   '//t.co/nfncsoh5rs'],
#  ['rt',
#   '@',
#   'pkfreestyleiro',
#   ':',
#   'eu',
#   'saindo',
#   'da',
#   'sua',
#   'vida',
#   'mas',
#   'em',
#   'camera',
#   'lenta',
#   'esperando',
#   'voce',
#   'pedir',
#   'pra',
#   'eu',
#   'ficar',
#   'https',
#   ':',
#   '//t.co/vvcwvxsvei'],
#  ['@',
#   'lgrillo2006',
#   '@',
#   'brunoteixeiraxx',
#   '@',
#   'xmfcklx',
#   '@',
#   'vascodagama',
#   'infelizmente',
#   'a',
#   'camera',
#   'nao',
#   'mostrou',
#   'por',
#   'cima',
#   ',',
#   'fico',
#   'devendo',
#   'essa',
#   'explicacao',
#   'auhahuau'],
#  ['rt',
#   '@',
#   'vivi_scans',
#   ':',
#   'o',
#   'auge',
#   'gente',
#   '!',
#   '!',
#   '!',
#   '!',
#   'tirei',
#   'uma',
#   'foto',
#   'com',
#   'o',
#   '@',
#   'guilhermeboulos',
#   'e',
#   'ganhei',
#   'um',
#   'abraco',
#   'dele',
#   '.',
#   '[',
#   '?',
#   ']',
#   'obs',
#   '.',
#   ':',
#   'ele',
#   'esperou',
#   'pacientemente',
#   'eu',
#   'col',
#   '...'],
#  ['rt',
#   '@',
#   'dehxxx',
#   ':',
#   'gente',
#   'no',
#   'show',
#   'do',
#   'dia',
#   '25',
#   'eu',
#   'tava',
#   'tentando',
#   'achar',
#   'o',
#   'final',
#   'da',
#   'fila',
#   ',',
#   'ai',
#   'tinha',
#   'um',
#   'cara',
#   'com',
#   'uma',
#   'camera',
#   'grande',
#   'e',
#   'de',
#   'tracos',
#   'asiaticos',
#   '.',
#   'e',
#   '...'],
#  ['rt',
#   '@',
#   'giumsantos',
#   ':',
#   'parece',
#   'que',
#   'eu',
#   'to',
#   'vivendo',
#   'em',
#   'camera',
#   'lenta',
#   'mas',
#   'meu',
#   'cerebro',
#   'ta',
#   'a',
#   'mil',
#   'por',
#   'hora'],
#  ['pra',
#   'mais',
#   'um',
#   'enfrentamento',
#   ':',
#   'falei',
#   'com',
#   'a',
#   'camera',
#   'do',
#   'celular',
#   'e',
#   'postei',
#   'nos',
#   'stories',
#   '...',
#   'prometi',
#   'pra',
#   'mim',
#   'que',
#   'me',
#   'jogaria',
#   'de',
#   'cabeca',
#   'pra',
#   'enfrentar',
#   'tudo',
#   'tudo',
#   ',',
#   'chega',
#   'a',
#   'mao',
#   'sua',
#   '.'],
#  ['rt',
#   '@',
#   'lucasmzanella',
#   ':',
#   'xiaomi',
#   'lancou',
#   'o',
#   'mi',
#   'note',
#   '10',
#   'que',
#   'no',
#   'exterior',
#   'custa',
#   'r',
#   '$',
#   '1600',
#   ',',
#   'camera',
#   'de',
#   '108',
#   'megapixels',
#   'com',
#   'nota',
#   'maxima',
#   'no',
#   'ranking',
#   'dxomark',
#   ',',
#   '12',
#   '...'],
#  ['eu',
#   'amo',
#   'a',
#   'tulla',
#   'luana',
#   'cuspindo',
#   'na',
#   'camera',
#   'kkkkkkkkkkkk'],
#  ['esses',
#   'lifestyle',
#   'desliga',
#   'a',
#   'camera',
#   'e',
#   'acende',
#   'um',
#   'cigarro',
#   'https',
#   ':',
#   '//t.co/cdx11o46lw'],
#  ['rt',
#   '@',
#   'eaibrow_',
#   ':',
#   'vcs',
#   'tambem',
#   'sentem',
#   'que',
#   'a',
#   'camera',
#   'do',
#   'iphone',
#   'vai',
#   'perdendo',
#   'a',
#   'qualidade',
#   'conforme',
#   'o',
#   'tempo',
#   'passa',
#   '?'],
#  ['@',
#   'marav1lhosa',
#   '@',
#   'edspellegrini',
#   '@',
#   'angelalbie',
#   'assim',
#   'q',
#   'eu',
#   'me',
#   'senti',
#   'caindo',
#   'da',
#   'escada',
#   'mas',
#   'em',
#   'camera',
#   'lenta'],
#  ['camera',
#   'nao',
#   'grava',
#   'o',
#   'henrique',
#   'dourado',
#   'sou',
#   'viuva',
#   'dele',
#   'mesmo',
#   'ele',
#   'sendo',
#   'ruim'],
#  ['fala',
#   ',',
#   'rapazeada',
#   '.',
#   'live',
#   'ta',
#   'on',
#   ',',
#   'vou',
#   'streamar',
#   'sem',
#   'camera',
#   'pq',
#   'to',
#   'morrendo',
#   'de',
#   'dor',
#   ',',
#   'se',
#   'passar',
#   'a',
#   'dor',
#   'eu',
#   'ligo',
#   'a',
#   'cam',
#   'mais',
#   'tarde',
#   '&',
#   'lt',
#   ';',
#   '3',
#   'chega',
#   'ai',
#   'pra',
#   'ver',
#   'uma',
#   'gameplay',
#   'criminosa',
#   'de',
#   'fiddle',
#   'vc',
#   'diria',
#   'nao',
#   'para',
#   'este',
#   'jovem',
#   'projeto',
#   'de',
#   'mono',
#   'fiddle',
#   '?',
#   'https',
#   ':',
#   '//t.co/xjj7idig7z',
#   'https',
#   ':',
#   '//t.co/xjj7idig7z',
#   'https',
#   ':',
#   '//t.co/txetvf1twk'],
#  ['@',
#   'pizzz2009',
#   '@',
#   'hfloret',
#   'porra',
#   'e',
#   'impossivel',
#   'nao',
#   'ver',
#   ',',
#   'a',
#   'camera',
#   'focou',
#   'no',
#   'cruzamento',
#   'do',
#   'pikachu'],
#  ['rt',
#   '@',
#   'eoq_bangtan2',
#   ':',
#   'eu',
#   'nunca',
#   'achei',
#   'que',
#   'eu',
#   'fosse',
#   'amar',
#   'tanto',
#   'uma',
#   'camera',
#   'por',
#   'esse',
#   'angulo',
#   ',',
#   'todos',
#   'tao',
#   'piticos',
#   'se',
#   'divertindo',
#   '@',
#   'bts_twt',
#   '#',
#   'bts',
#   'https',
#   '...'],
#  ['@',
#   'nandoohliimah',
#   'um',
#   'operador',
#   'de',
#   'camera',
#   '.',
#   'nao',
#   'vao',
#   'revelar',
#   'a',
#   'identidade',
#   '.'],
#  ['fodase', 'vo', 'tirar', 'o', 'adesivo', 'da', 'camera', 'do', 'notebook'],
#  ['so',
#   'tem',
#   '2',
#   'lugares',
#   'em',
#   'que',
#   'eu',
#   'fico',
#   'bonita',
#   'que',
#   'sao',
#   'camera',
#   'de',
#   'iphone',
#   'e',
#   'retrovisor',
#   'de',
#   'carro'],
#  ['rt',
#   '@',
#   'malditopt',
#   ':',
#   'a',
#   'agenda',
#   'esquerdista',
#   'entra',
#   'em',
#   'tilt',
#   'quando',
#   'acontece',
#   'algo',
#   'assim',
#   '.',
#   'operador',
#   'de',
#   'camera',
#   'que',
#   'chamou',
#   'sabrina',
#   'de',
#   '``',
#   'macaca',
#   "''",
#   'na',
#   'fazenda',
#   '...'],
#  ['rt',
#   '@',
#   'eoq_bangtan2',
#   ':',
#   'eu',
#   'nunca',
#   'achei',
#   'que',
#   'eu',
#   'fosse',
#   'amar',
#   'tanto',
#   'uma',
#   'camera',
#   'por',
#   'esse',
#   'angulo',
#   ',',
#   'todos',
#   'tao',
#   'piticos',
#   'se',
#   'divertindo',
#   '@',
#   'bts_twt',
#   '#',
#   'bts',
#   'https',
#   '...'],
#  ['rt',
#   '@',
#   'biasscosta',
#   ':',
#   'no',
#   'espelho',
#   '//',
#   'na',
#   'camera',
#   'https',
#   ':',
#   '//t.co/iljmynrmtj'],
#  ['saudade', 'de', 'qando', 'eu', 'tinha', 'camera', 'no', 'meu', 'celular'],
#  ['rt',
#   '@',
#   'enzo_gb09',
#   ':',
#   '11',
#   'segundo',
#   'dessa',
#   'cantando',
#   'na',
#   'direcao',
#   'da',
#   'camera',
#   'dos',
#   'deputados',
#   'com',
#   'todos',
#   'eles',
#   'la',
#   'dentro',
#   '!',
#   'https',
#   ':',
#   '//t.co/yd9ca1qas1'],
#  ['fui',
#   'p',
#   'colegio',
#   'e',
#   'esqueci',
#   'a',
#   'preta',
#   'trancada',
#   'dentro',
#   'de',
#   'casa',
#   ',',
#   'agr',
#   'estamos',
#   'vendo',
#   'as',
#   'fotos',
#   'na',
#   'camera',
#   'na',
#   'sala',
#   'e',
#   'esta',
#   'ela',
#   'linda',
#   'e',
#   'bela',
#   'dormindo',
#   'no',
#   'sofa'],
#  ['camera',
#   'bosta',
#   'que',
#   'nao',
#   'capta',
#   'toda',
#   'a',
#   'beleza',
#   'desse',
#   'ser',
#   'https',
#   ':',
#   '//t.co/pxflj7abby'],
#  ['@',
#   'gabriel951silva',
#   '@',
#   'nanda_corleone',
#   'olha',
#   'meu',
#   'bem',
#   ',',
#   'ninguem',
#   'aqui',
#   'esta',
#   'acusando',
#   'a',
#   'menina',
#   ',',
#   'apenas',
#   'dizendo',
#   'a',
#   'realidade',
#   ',',
#   'em',
#   'nenhum',
#   'momento',
#   'disse',
#   'q',
#   'ela',
#   'nao',
#   'foi',
#   'assediada',
#   ',',
#   'apenas',
#   'que',
#   'muitas',
#   'dao',
#   'confianca',
#   'e',
#   'depois',
#   'se',
#   'fazem',
#   'de',
#   'vitima',
#   ',',
#   'como',
#   'disse',
#   'ali',
#   'encima',
#   ',',
#   'ela',
#   'te',
#   'que',
#   'ter',
#   'provas',
#   'como',
#   'camera',
#   ',',
#   'e',
#   'vai',
#   'a',
#   'justica',
#   '!',
#   '!',
#   'simples'],
#  ['rt',
#   '@',
#   'taesarty',
#   ':',
#   'o',
#   'jungkook',
#   'ficou',
#   'olhando',
#   'pro',
#   'tae',
#   'pelo',
#   'telao',
#   'ate',
#   'a',
#   'camera',
#   'parar',
#   'de',
#   'focar',
#   'nele',
#   ',',
#   'eu',
#   'to',
#   'triste',
#   'pra',
#   'caralho',
#   'https',
#   ':',
#   '//t.co/o6bnpw3b67'],
#  ['tudo',
#   'p',
#   'mim',
#   'josh',
#   'e',
#   'noah',
#   'cantando',
#   'baby',
#   'no',
#   'cmc',
#   'do',
#   'ep',
#   'hoje',
#   'e',
#   'logo',
#   'depois',
#   'o',
#   'bailey',
#   'todo',
#   'bb',
#   'brincando',
#   'com',
#   'a',
#   'camera',
#   'ai',
#   'olha',
#   'sinceramente',
#   '...'],
#  ['@',
#   'ilse_sep',
#   'na',
#   'camera',
#   'do',
#   'canto',
#   'da',
#   'bem',
#   'pior',
#   'que',
#   'a',
#   'geral'],
#  ['rt',
#   '@',
#   'hilu_hilu',
#   ':',
#   'mas',
#   'gente',
#   'falando',
#   'serio',
#   ':',
#   'eu',
#   'ainda',
#   'nao',
#   'cheguei',
#   'em',
#   'nem',
#   '50',
#   '%',
#   'da',
#   'minha',
#   'vaquinha',
#   'pra',
#   'recuperar',
#   'os',
#   'itens',
#   'que',
#   'me',
#   'roubaram',
#   '.',
#   'o',
#   'noteboo',
#   '...'],
#  ['a',
#   'agenda',
#   'esquerdista',
#   'entra',
#   'em',
#   'tilt',
#   'quando',
#   'acontece',
#   'algo',
#   'assim',
#   '.',
#   'operador',
#   'de',
#   'camera',
#   'que',
#   'chamou',
#   'sabrina',
#   'de',
#   '``',
#   'macaca',
#   "''",
#   'na',
#   'fazenda',
#   'tambem',
#   'e',
#   'negro',
#   'https',
#   ':',
#   '//t.co/q0d0wkz4lf',
#   'via',
#   '@',
#   'uoltvefamosos',
#   '@',
#   'uol'],
#  ['@', 'luanamoromizato', 'olhano', 'p', 'camera', 'fica', 'mais', 'bonits'],
#  ['``',
#   'novinho',
#   'se',
#   'fode',
#   'gostoso',
#   'na',
#   'prova',
#   'do',
#   'enem',
#   'ao',
#   'vivo',
#   'no',
#   'camera',
#   'prive',
#   "''"],
#  ['rt',
# ...
#   '#',
#   'gahyeon',
#   '``',
#   'eu',
#   'tive',
#   'um',
#   'tem',
#   '...'],
#  ['rt',
#   '@',
#   'mauricioricardo',
#   ':',
#   'damares',
#   'no',
#   'tinder',
#   'faz',
#   'todo',
#   'o',
#   'sentido',
#   '.',
#   'todos',
#   'no',
#   'aplicativo',
#   'so',
#   'quer',
#   'saber',
#   'de',
#   'sacanagem',
#   '.',
#   'existe',
#   'sacanagem',
#   'maior',
#   'que',
#   'a',
#   'mul',
#   '...'],
#  ['estou',
#   'procurando',
#   'aplicativo',
#   'para',
#   'anotar',
#   'meus',
#   'gastos',
#   'mas',
#   'nao',
#   'acho',
#   'nenhum',
#   'do',
#   'jeito',
#   'que',
#   'eu',
#   'quero'],
#  ['meu',
#   'whatsapp',
#   'tava',
#   'toda',
#   'hora',
#   'desconectando',
#   'da',
#   'minha',
#   'conta',
#   'ai',
#   'eu',
#   'fui',
#   'e',
#   'tirei',
#   'a',
#   'versao',
#   'beta',
#   ',',
#   'agora',
#   'o',
#   'aplicativo',
#   'nem',
#   'abre',
#   'mano',
#   'vai',
#   'tomar',
#   'no',
#   'cu'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['esse', 'aplicativo', 'do', '99', 'e', 'uma', 'desgraca', 'isso', 'sim'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['eu',
#   'fiquei',
#   'um',
#   'tempo',
#   'tentando',
#   'explicar',
#   'pra',
#   'ele',
#   'que',
#   'tinha',
#   'passado',
#   ',',
#   'pq',
#   'descontou',
#   'do',
#   'meu',
#   'saldo',
#   'e',
#   'estava',
#   'la',
#   'o',
#   'comprovante',
#   'no',
#   'meu',
#   'aplicativo'],
#  ['06/11',
#   'l',
#   'foto/traducao',
#   '-',
#   'atualizacao',
#   'da',
#   'gahyeon',
#   'no',
#   'aplicativo',
#   'do',
#   'dreamcatcher',
#   '#',
#   'dreamcatcher',
#   '#',
#   'deurimkaecyeo',
#   '#',
#   'gahyeon',
#   '``',
#   'eu',
#   'tive',
#   'um',
#   'tempo',
#   'divertido',
#   'com',
#   'os',
#   'somnies',
#   'de',
#   'paris',
#   '!',
#   '!',
#   'hhehheh',
#   "''",
#   'https',
#   ':',
#   '//t.co/ug1vociidh',
#   'trans',
#   'eng',
#   ':',
#   '7_dreamers',
#   'https',
#   ':',
#   '//t.co/3mgyhz24jn'],
#  ['rt',
#   '@',
#   'guiicalxj',
#   ':',
#   'curso',
#   'aplicativo',
#   'delivery',
#   ',',
#   'aqui',
#   'voce',
#   'vai',
#   'aprender',
#   'a',
#   'como',
#   'criar',
#   'um',
#   'app',
#   'para',
#   'estabelecimentos',
#   'como',
#   'pizzaria',
#   ',',
#   'lancherias',
#   ',',
#   'mini',
#   '...'],
#  ['rt',
#   '@',
#   'btsbr_official',
#   ':',
#   'minutos',
#   'cada',
#   '.',
#   '#',
#   'disponivel',
#   'para',
#   'celular',
#   'e',
#   'computadores',
#   '.',
#   '#',
#   'a',
#   'pre-venda',
#   'ja',
#   'esta',
#   'disponivel',
#   ',',
#   'no',
#   'aplicativo',
#   'weply',
#   ',',
#   'por',
#   'aprox',
#   '...'],
#  ['rt',
#   '@',
#   'crisoli50795432',
#   ':',
#   'monbebes',
#   '!',
#   'por',
#   'favor',
#   ',',
#   'va',
#   'para',
#   'o',
#   'aplicativo',
#   'starplay',
#   'e',
#   'vote',
#   'no',
#   'wonho',
#   '!',
#   '!',
#   '!',
#   'o',
#   'premio',
#   'em',
#   'primeiro',
#   'lugar',
#   'e',
#   'o',
#   'de',
#   'midia',
#   ',',
#   'o',
#   'que',
#   '...'],
#  ['@',
#   'spotifyajuda',
#   'que',
#   'porra',
#   'e',
#   'essa',
#   ',',
#   'querida',
#   '?',
#   'tenho',
#   'uma',
#   'playlist',
#   'e',
#   'todas',
#   'as',
#   'musicas',
#   'estao',
#   'assim',
#   '!',
#   'toca',
#   '15',
#   'segundos',
#   'de',
#   'musica',
#   'e',
#   'para',
#   '.',
#   'depois',
#   'de',
#   '3',
#   'minutos',
#   'toca',
#   '5',
#   'segundo',
#   'de',
#   'musica',
#   ',',
#   'e',
#   'assim',
#   'ate',
#   'ela',
#   'acabar',
#   ',',
#   'nao',
#   ',',
#   'minha',
#   'internet',
#   'nao',
#   'ta',
#   'lenta',
#   '...',
#   'eu',
#   'uso',
#   'o',
#   'aplicativo',
#   'do',
#   'spotify',
#   'para',
#   'windows',
#   '10',
#   'https',
#   ':',
#   '//t.co/xlloaxhlho'],
#  ['@',
#   'juniorafonso12',
#   '@',
#   'urubuninhocrf',
#   '@',
#   'bellaisafla',
#   '@',
#   'canal_11oficial',
#   '1o',
#   'baixe',
#   'algum',
#   'aplicativo',
#   'vpn',
#   ';',
#   '2o',
#   'coloque',
#   'sua',
#   'localizacao',
#   'diretamente',
#   'pelo',
#   'aplicativo',
#   'em',
#   'outro',
#   'pais',
#   '(',
#   'menos',
#   'portugal',
#   ')',
#   ';',
#   '3o',
#   'entre',
#   'no',
#   'youtube',
#   'e',
#   'procure',
#   'flatv',
#   ';',
#   '4o',
#   'assista',
#   'tranquilamente',
#   '.'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['pq',
#   'nao',
#   'sou',
#   'verificada',
#   'neste',
#   'aplicativo',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['@',
#   'ofelipemesquita',
#   '@',
#   'urubuninhocrf',
#   '@',
#   'bellaisafla',
#   '@',
#   'canal_11oficial',
#   '1o',
#   'baixe',
#   'algum',
#   'aplicativo',
#   'vpn',
#   ';',
#   '2o',
#   'coloque',
#   'sua',
#   'localizacao',
#   'diretamente',
#   'pelo',
#   'aplicativo',
#   'em',
#   'outro',
#   'pais',
#   '(',
#   'menos',
#   'portugal',
#   ')',
#   ';',
#   '3o',
#   'entre',
#   'no',
#   'youtube',
#   'e',
#   'procure',
#   'flatv',
#   ';',
#   '4o',
#   'assista',
#   'tranquilamente',
#   '.'],
#  ['rt',
#   '@',
#   'liarsperk',
#   ':',
#   'esse',
#   'aplicativo',
#   'salvou',
#   'a',
#   'minha',
#   'vida',
#   'https',
#   ':',
#   '//t.co/zhpo61wgr1'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['@',
#   'ivankafaei',
#   'eu',
#   'tentei',
#   'baixar',
#   'um',
#   'pra',
#   'ver',
#   'scc',
#   'junto',
#   'com',
#   'o',
#   'nikolas',
#   'e',
#   'eu',
#   'nunca',
#   'vi',
#   'um',
#   'aplicativo',
#   'tao',
#   'imbecil',
#   'na',
#   'minha',
#   'vida'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['minutos',
#   'cada',
#   '.',
#   '#',
#   'disponivel',
#   'para',
#   'celular',
#   'e',
#   'computadores',
#   '.',
#   '#',
#   'a',
#   'pre-venda',
#   'ja',
#   'esta',
#   'disponivel',
#   ',',
#   'no',
#   'aplicativo',
#   'weply',
#   ',',
#   'por',
#   'aproximadamente',
#   'r',
#   '$',
#   '81,00',
#   '(',
#   'pacote',
#   'completo',
#   ')',
#   '#',
#   'nao',
#   'ha',
#   'informacoes',
#   'sobre',
#   'as',
#   'legendas',
#   '.',
#   'possivelmente',
#   '-',
#   'e',
#   'infelizmente',
#   '-',
#   'nao',
#   'tera',
#   'em',
#   'portugues',
#   ',',
#   'mas',
#   'nada',
#   'confirmado',
#   '.'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['@',
#   'yaenseok',
#   '@',
#   'sunchildjh',
#   '@',
#   'myarisbts',
#   'e',
#   'um',
#   'aplicativo',
#   'q',
#   'e',
#   'uma',
#   'loja',
#   'virtual',
#   'kkkkk',
#   'mas',
#   'so',
#   'vende',
#   'coisa',
#   'do',
#   'bts',
#   'e',
#   'do',
#   'txt',
#   'e',
#   'a',
#   'loja',
#   'oficial',
#   'deles'],
#  ['@', 'princesaabru', 'que', 'aplicativo', 'e', 'esse', '?'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['@',
#   'guirizzi',
#   'poxa',
#   ',',
#   '@',
#   'guirizzi',
#   '!',
#   'para',
#   'que',
#   'possamos',
#   'te',
#   'ajudar',
#   'sobre',
#   'isso',
#   ',',
#   'pedimos',
#   'que',
#   'entre',
#   'em',
#   'contato',
#   'pelo',
#   'aplicativo',
#   'ou',
#   'pelo',
#   'site',
#   ':',
#   'https',
#   ':',
#   '//t.co/4y2i9yfldg'],
#  ['rt',
#   '@',
#   'vulgolc17',
#   ':',
#   'pg',
#   'estava',
#   'na',
#   'conta',
#   'e',
#   'eu',
#   'nem',
#   'sabia',
#   'pq',
#   'a',
#   'bia',
#   'bloqueou',
#   'meu',
#   'aplicativo',
#   'do',
#   'banco',
#   '[',
#   '?',
#   ']'],
#  ['@',
#   'nubank',
#   'obrigado',
#   'pelos',
#   'meus',
#   'estresses',
#   'do',
#   'dia',
#   '.',
#   'nenhum',
#   'boleto',
#   'do',
#   'aplicativo',
#   'de',
#   'vcs/transferencia',
#   'ta',
#   'funcionando',
#   'direito',
#   '.',
#   'parabens',
#   '2',
#   'estrelas'],
#  ['rt',
#   '@',
#   'maistorcedoras',
#   ':',
#   'oi',
#   'gente',
#   '!',
#   '!',
#   'somos',
#   'um',
#   'aplicativo',
#   'em',
#   'desenvolvimento',
#   'e',
#   'o',
#   'nosso',
#   'objetivo',
#   'e',
#   'unir',
#   'e',
#   'aumentar',
#   'a',
#   'representatividade',
#   'feminina',
#   'n',
#   '...'],
#  ['brinde',
#   'gratis',
#   '!',
#   'continue',
#   'lendo',
#   'baixe',
#   'o',
#   'aplicativo',
#   'clicando',
#   'no',
#   'link',
#   'abaixo',
#   ',',
#   'https',
#   ':',
#   '//t.co/gjooljusjj',
#   'para',
#   'voce',
#   'ter',
#   ':',
#   'conta',
#   'digital',
#   'gratis',
#   '+',
#   'cartao',
#   'gratis',
#   '+',
#   'r',
#   '$',
#   '20,00',
#   'reais',
#   'para',
#   'voce',
#   'fazer',
#   'uma',
#   'recarga',
#   'de',
#   'celular',
#   'ou',
#   'pagar',
#   'uma',
#   'conta',
#   '!',
#   'click',
#   'aqui',
#   'para',
#   'ganhar'],
#  ['se',
#   'me',
#   'seguir',
#   'eu',
#   'vou',
#   'seguir',
#   'de',
#   'boa',
#   ',',
#   'se',
#   'parar',
#   'de',
#   'me',
#   'seguir',
#   'meu',
#   'aplicativo',
#   'avisa',
#   'logo',
#   '!',
#   '!',
#   '!',
#   '!',
#   '[',
#   '?',
#   ']',
#   '[',
#   '?',
#   ']',
#   '[',
#   '?',
#   ']',
#   '[',
#   '?',
#   ']'],
#  ['cartola', 'e', 'o', 'estresse', 'em', 'aplicativo'],
#  ['rt',
#   '@',
#   'maurocezar',
#   ':',
#   'bruno',
#   'henrique',
#   '(',
#   '@',
#   'brunohenrique',
#   ')',
#   'no',
#   'flamengo',
#   'faz',
#   'gols',
#   'em',
#   'jogos',
#   'grandes',
#   'e',
#   'classicos',
#   '.',
#   'o',
#   'dois',
#   'primeiros',
#   'foram',
#   'em',
#   'janeiro',
#   ',',
#   'contr',
#   '...'],
#  ['meu', 'aplicativo', 'esta', 'travando', 'demais', ',', 'por', 'ceus', '.'],
#  ['rt',
#   '@',
#   'dcatcherbr',
#   ':',
#   '06/11',
#   'l',
#   'foto/traducao',
#   '-',
#   'atualizacao',
#   'da',
#   'dami',
#   'no',
#   'aplicativo',
#   'do',
#   'dreamcatcher',
#   '#',
#   'dreamcatcher',
#   '#',
#   'deurimkaecyeo',
#   '#',
#   'dami',
#   '``',
#   'tomem',
#   'cuidado',
#   '!',
#   'nao',
#   'f',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['a',
#   'mensagem',
#   "'",
#   'o',
#   'deus',
#   'do',
#   'impossivel',
#   "'",
#   'vai',
#   'mexer',
#   'com',
#   'a',
#   'sua',
#   'fe',
#   'e',
#   'com',
#   'as',
#   'suas',
#   'emocoes',
#   '!',
#   'baixe',
#   'o',
#   'aplicativo',
#   'e',
#   'confira',
#   ',',
#   'as',
#   '22h30',
#   ',',
#   'este',
#   'estudo',
#   'na',
#   '@',
#   'radiofelizfm',
#   'https',
#   ':',
#   '//t.co/uhynt2ffki'],
#  ['rt',
#   '@',
#   'bunny_2038',
#   ':',
#   'nerve',
#   'fack',
#   'au',
#   'onde',
#   'jack',
#   ',',
#   'um',
#   'ator',
#   'famoso',
#   ',',
#   'acidentalmente',
#   'aceita',
#   'um',
#   'desafio',
#   'em',
#   'um',
#   'aplicativo',
#   'nao',
#   'sabendo',
#   'que',
#   'nao',
#   'fazer',
#   'resul',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['rt',
#   '@',
#   'mila_oliveira11',
#   ':',
#   'tao',
#   'facil',
#   'ver',
#   'que',
#   'o',
#   'mundo',
#   'e',
#   'um',
#   'presidio',
#   'e',
#   'que',
#   'esses',
#   'altos',
#   'edificios',
#   'sao',
#   'um',
#   'convite',
#   'ao',
#   'suicidio',
#   'aos',
#   'ares',
#   ',',
#   'observa',
#   'quant',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['@',
#   'aschmidt_',
#   '@',
#   'nubank',
#   'eeeee',
#   'o',
#   'nubank',
#   'fez',
#   'o',
#   'suporte',
#   'no',
#   'aplicativo',
#   'e',
#   'nao',
#   'resolveu',
#   '.',
#   'paguei',
#   'minha',
#   'fatura',
#   'e',
#   'o',
#   'limite',
#   'nao',
#   'apareceu',
#   '.',
#   'complicado',
#   'ne',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['rt',
#   '@',
#   'mila_oliveira11',
#   ':',
#   'tao',
#   'facil',
#   'ver',
#   'que',
#   'o',
#   'mundo',
#   'e',
#   'um',
#   'presidio',
#   'e',
#   'que',
#   'esses',
#   'altos',
#   'edificios',
#   'sao',
#   'um',
#   'convite',
#   'ao',
#   'suicidio',
#   'aos',
#   'ares',
#   ',',
#   'observa',
#   'quant',
#   '...'],
#  ['rt',
#   '@',
#   'eumonabrisa',
#   ':',
#   'galera',
#   'atencao',
#   ',',
#   'uma',
#   'coisinha',
#   'legal',
#   'pra',
#   'vcs',
#   'seguinte',
#   ',',
#   'tem',
#   'um',
#   'aplicativo',
#   'chamando',
#   '``',
#   'quize',
#   "''",
#   'um',
#   'joguinho',
#   'de',
#   'perguntas',
#   'que',
#   'ga',
#   '...'],
#  ['a',
#   'socialite',
#   'kim',
#   'kardashian',
#   'processou',
#   'a',
#   'desenvolvedora',
#   'ihandy',
#   'pelo',
#   'uso',
#   'nao',
#   'autorizado',
#   'de',
#   'uma',
#   'foto',
#   'https',
#   ':',
#   '//t.co/nvy40nix2v'],
#  ['@',
#   'uber_support',
#   'preciso',
#   'entrar',
#   'em',
#   'contato',
#   'urgente',
#   'e',
#   'nao',
#   'consigo',
#   '.',
#   'pior',
#   'aplicativo',
#   'de',
#   'delivery',
#   'de',
#   'comida',
#   '.',
#   'depois',
#   'de',
#   'fazer',
#   'o',
#   'pedido',
#   ',',
#   'vi',
#   'que',
#   'o',
#   'restaurante',
#   'onde',
#   'fiz',
#   'o',
#   'pedido',
#   'fica',
#   'a',
#   '3h',
#   'de',
#   'distancia',
#   '.'],
#  ['alguem',
#   'conhece',
#   'um',
#   'aplicativo',
#   'de',
#   'transmissao',
#   'para',
#   'a',
#   'tv',
#   'que',
#   'de',
#   'pra',
#   'acelerar/alentecer',
#   'os',
#   'videos',
#   '?'],
#  ['06/11',
#   'l',
#   'foto/traducao',
#   '-',
#   'atualizacao',
#   'da',
#   'dami',
#   'no',
#   'aplicativo',
#   'do',
#   'dreamcatcher',
#   '#',
#   'dreamcatcher',
#   '#',
#   'deurimkaecyeo',
#   '#',
#   'dami',
#   '``',
#   'tomem',
#   'cuidado',
#   '!',
#   'nao',
#   'fiquem',
#   'doentes',
#   '!',
#   '!',
#   '!',
#   "''",
#   'https',
#   ':',
#   '//t.co/rfwsg9zioj',
#   'trans',
#   'eng',
#   ':',
#   '7_dreamers',
#   'https',
#   ':',
#   '//t.co/lsw2uxivdj'],
#  ['rt',
#   '@',
#   'liarsperk',
#   ':',
#   'esse',
#   'aplicativo',
#   'salvou',
#   'a',
#   'minha',
#   'vida',
#   'https',
#   ':',
#   '//t.co/zhpo61wgr1'],
#  ['alguem',
#   'baixa',
#   'e',
#   'me',
#   'manda',
#   'pelo',
#   'amor',
#   'de',
#   'deus',
#   'kkkkkkk',
#   'to',
#   'sem',
#   'aplicativo',
#   'https',
#   ':',
#   '//t.co/c7uxcbno3u'],
#  ['rt',
#   '@',
#   'nenm81507080',
#   ':',
#   'oi',
#   'galera',
#   'tutupom',
#   '?',
#   'eu',
#   'preciso',
#   'que',
#   'vcs',
#   'me',
#   'ajudem',
#   'a',
#   'compartilhar',
#   'esse',
#   'video',
#   ',',
#   'preciso',
#   'de',
#   'votos',
#   'caso',
#   'eu',
#   'nao',
#   'seje',
#   'selecionada',
#   '...'],
#  ['rt',
#   '@',
#   'mauricioricardo',
#   ':',
#   'damares',
#   'no',
#   'tinder',
#   'faz',
#   'todo',
#   'o',
#   'sentido',
#   '.',
#   'todos',
#   'no',
#   'aplicativo',
#   'so',
#   'quer',
#   'saber',
#   'de',
#   'sacanagem',
#   '.',
#   'existe',
#   'sacanagem',
#   'maior',
#   'que',
#   'a',
#   'mul',
#   '...'],
#  []]

# %%
#most common words

words = []
for e in tmp_text:
    words.extend(e)

common_words = collections.Counter(words).most_common()

print(len(words))
print('---------')
print(common_words[:30])
# Out:
# 17539
# ---------
# [(':', 542), ('@', 540), ('e', 524), ('de', 437), (',', 414), ('o', 398), ('a', 354), ('que', 329), ('eu', 320), ('rt', 301), ('do', 277), ('...', 221), ('um', 220), ('camera', 197), ('pra', 174), ('no', 171), ('nao', 168), ('?', 168), ('.', 166), ('https', 158), ('com', 150), ('celular', 142), ('meu', 141), ('na', 138), ('uma', 125), ('em', 116), ('da', 110), ('iphone', 109), ('notebook', 101), ('memoria', 97)]

# %%
#building dictionary
vocab_size = 10_000

w_vocab = common_words[:(vocab_size-1)]

w_vocab
# Out:
# [(':', 542),
#  ('@', 540),
#  ('e', 524),
#  ('de', 437),
#  (',', 414),
#  ('o', 398),
#  ('a', 354),
#  ('que', 329),
#  ('eu', 320),
#  ('rt', 301),
#  ('do', 277),
#  ('...', 221),
#  ('um', 220),
#  ('camera', 197),
#  ('pra', 174),
#  ('no', 171),
#  ('nao', 168),
#  ('?', 168),
#  ('.', 166),
#  ('https', 158),
#  ('com', 150),
#  ('celular', 142),
#  ('meu', 141),
#  ('na', 138),
#  ('uma', 125),
#  ('em', 116),
#  ('da', 110),
#  ('iphone', 109),
#  ('notebook', 101),
#  ('memoria', 97),
#  ('!', 94),
#  ('se', 94),
#  ('aplicativo', 91),
#  ('ventilador', 88),
#  ('tem', 84),
#  ('q', 77),
#  ('mas', 72),
#  ('ja', 68),
#  ('minha', 67),
#  ('me', 67),
#  ('so', 67),
#  ('ta', 58),
#  ('ele', 58),
#  ('``', 58),
#  ('por', 57),
#  ('mais', 56),
#  ('#', 56),
#  ("''", 53),
#  ('todo', 50),
#  ('esta', 49),
#  ('vcs', 49),
#  ('to', 47),
#  ('gente', 46),
#  ('para', 44),
#  ('ou', 43),
#  ('ai', 42),
#  ('quem', 42),
#  ('cabeca', 41),
#  ('ate', 40),
#  ('tudo', 37),
#  ('como', 37),
#  ('dia', 36),
#  ('sem', 36),
#  ('as', 36),
#  ('ver', 36),
#  ('pq', 35),
#  ('tava', 35),
#  ('esse', 32),
#  ('vai', 31),
#  ('nada', 31),
#  ('n', 30),
#  ('voce', 29),
#  ('ela', 29),
#  ('nem', 28),
#  ('cair', 28),
#  ('bem', 28),
#  ('assim', 28),
#  ('isso', 28),
#  ('essa', 27),
#  ('quando', 27),
#  ('escola', 27),
#  ('tinha', 27),
#  ('os', 26),
#  ('ter', 26),
#  ('muito', 26),
#  ('medo', 26),
#  ('baixo', 26),
#  ('cara', 25),
#  ('galera', 25),
#  ('panicnbhd', 25),
#  ('sair', 25),
#  ('casa', 24),
#  ('tenho', 24),
#  ('boa', 24),
#  ('pelo', 24),
#  ('dos', 24),
#  ('pessoa', 24),
#  ('estudante', 24),
#  ('publica', 24),
#  ('voando', 24),
#  ('decapitar', 24),
#  ('vou', 23),
#  ('sou', 23),
#  ('maior', 22),
#  ('sao', 22),
#  ('11', 22),
#  ('dentro', 21),
#  ('tentando', 21),
#  ('lado', 20),
#  ('ficar', 20),
#  ('[', 20),
#  (']', 20),
#  ('sua', 20),
#  ('seguinte', 20),
#  ('atencao', 20),
#  ('mexer', 19),
#  ('fazer', 19),
#  ('ganhar', 19),
#  ('queria', 19),
#  ('p', 19),
#  ('te', 19),
#  ('grande', 19),
#  ('eumonabrisa', 19),
#  ('coisinha', 19),
#  ('legal', 19),
#  ('chamando', 19),
#  ('quize', 19),
#  ('joguinho', 19),
#  ('perguntas', 19),
#  ('ga', 19),
#  ('comprar', 18),
#  ('novo', 18),
#  ('tao', 18),
#  ('tambem', 18),
#  ('vc', 18),
#  ('foto', 18),
#  ('-', 18),
#  ('ainda', 17),
#  ('tipo', 17),
#  ('mesmo', 16),
#  ('preciso', 16),
#  ('nunca', 16),
#  ('achar', 16),
#  ('foi', 16),
#  ('fica', 16),
#  ('pode', 16),
#  ('pro', 16),
#  ('show', 16),
#  ('final', 16),
#  ('tracos', 16),
#  (';', 16),
#  ('pagar', 16),
#  ('porra', 15),
#  ('hoje', 15),
#  ('vida', 15),
#  ('(', 15),
#  ('mao', 15),
#  ('coisa', 15),
#  ('toda', 15),
#  ('tanto', 15),
#  ('mundo', 15),
#  ('top', 15),
#  ('arma', 14),
#  ('conceito', 14),
#  ('alguem', 14),
#  ('deus', 14),
#  ('acho', 14),
#  (')', 14),
#  ('aqui', 14),
#  ('mim', 14),
#  ('dehxxx', 14),
#  ('25', 14),
#  ('fila', 14),
#  ('asiaticos', 14),
#  ('nos', 14),
#  ('xiaomi', 14),
#  ('juizidoroo', 14),
#  ('deixam', 14),
#  ('oferece', 14),
#  ('acai', 14),
#  ('fi', 14),
#  ('confirmar', 14),
#  ('abrir', 14),
#  ('bullshhhit', 13),
#  ('micropenis', 13),
#  ('visto', 13),
#  ('//t.co/fphq0lvnv4', 13),
#  ('quer', 13),
#  ('merda', 13),
#  ('ser', 13),
#  ('fico', 13),
#  ('ne', 13),
#  ('vitormrtns', 13),
#  ('cansado', 13),
#  ('imagem', 13),
#  ('timeline', 13),
#  ('precisei', 13),
#  ('photoshop', 13),
#  ('c*rlos', 13),
#  ('bolson*ro', 13),
#  ('tirar', 12),
#  ('hora', 12),
#  ('fosse', 12),
#  ('faz', 12),
#  ('la', 12),
#  ('seu', 12),
#  ('porque', 12),
#  ('outro', 12),
#  ('todos', 12),
#  ('esses', 12),
#  ('pior', 11),
#  ('agora', 11),
#  ('quero', 11),
#  ('pegar', 11),
#  ('depois', 11),
#  ('deixar', 11),
#  ('passar', 10),
#  ('fazendo', 10),
#  ('bom', 10),
#  ('noite', 10),
#  ('usar', 10),
#  ('ia', 10),
#  ('lembro', 10),
#  ('sempre', 10),
#  ('tela', 10),
#  ('existe', 10),
#  ('pela', 10),
#  ('mt', 10),
#  ('10', 10),
#  ('tempo', 10),
#  ('pqp', 10),
#  ('olhando', 10),
#  ('bonita', 10),
#  ('vem', 10),
#  ('lenta', 10),
#  ('uns', 10),
#  ('dreamcatcher', 10),
#  ('%', 9),
#  ('trabalho', 9),
#  ('vezes', 9),
#  ('8', 9),
#  ('estou', 9),
#  ('ruim', 9),
#  ('fui', 9),
#  ('mano', 9),
#  ('apenas', 9),
#  ('dela', 9),
#  ('qual', 9),
#  ('saindo', 9),
#  ('ao', 9),
#  ('tu', 9),
#  ('kkkkkk', 9),
#  ('sim', 9),
#  ('bateria', 9),
#  ('dormir', 9),
#  ('disse', 9),
#  ('pai', 9),
#  ('vi', 9),
#  ('olha', 9),
#  ('+', 9),
#  ('nessa', 8),
#  ('gol', 8),
#  ('compra', 8),
#  ('qualquer', 8),
#  ('comprei', 8),
#  ('dois', 8),
#  ('apple', 8),
#  ('amo', 8),
#  ('operador', 8),
#  ('acontece', 8),
#  ('nenhum', 8),
#  ('atualizacao', 8),
#  ('calor', 8),
#  ('frente', 7),
#  ('eh', 7),
#  ('consigo', 7),
#  ('uso', 7),
#  ('2', 7),
#  ('sei', 7),
#  ('ligado', 7),
#  ('era', 7),
#  ('antes', 7),
#  ('menina', 7),
#  ('dificil', 7),
#  ('mae', 7),
#  ('bosta', 7),
#  ('fala', 7),
#  ('meus', 7),
#  ('massa', 7),
#  ('forca', 7),
#  ('eles', 7),
#  ('parece', 7),
#  ('algo', 7),
#  ('estao', 7),
#  ('caralho', 7),
#  ('mostrou', 7),
#  ('bts', 7),
#  ('sabrina', 7),
#  ('sala', 7),
#  ('primeira', 7),
#  ('50', 6),
#  ('fodase', 6),
#  ('vo', 6),
#  ('ceu', 6),
#  ('odio', 6),
#  ('vez', 6),
#  ('parar', 6),
#  ('kkkkk', 6),
#  ('video', 6),
#  ('ano', 6),
#  ('nesse', 6),
#  ('viu', 6),
#  ('mulher', 6),
#  ('3', 6),
#  ('oi', 6),
#  ('vendo', 6),
#  ('filho', 6),
#  ('//', 6),
#  ('tras', 6),
#  ('odeio', 6),
#  ('carregador', 6),
#  ('onde', 6),
#  ('conta', 6),
#  ('entao', 6),
#  ('quente', 6),
#  ('lixo', 6),
#  ('tinder', 6),
#  ('c', 6),
#  ('dele', 6),
#  ('jogo', 6),
#  ('cima', 6),
#  ('mi', 6),
#  ('custa', 6),
#  ('angulo', 6),
#  ('vao', 6),
#  ('chamou', 6),
#  ('macaca', 6),
#  ('fazenda', 6),
#  ('dessa', 6),
#  ('frontal', 6),
#  ('palmeiras', 6),
#  ('lance', 6),
#  ('var', 6),
#  ('branco', 6),
#  ('lugar', 6),
#  ('conseguindo', 6),
#  ('momentos', 6),
#  ('amor', 6),
#  ('mal', 6),
#  ('comida', 6),
#  ('imagina', 6),
#  ('baixe', 6),
#  ('comigo', 6),
#  ('cama', 6),
#  ('demais', 6),
#  ('facil', 6),
#  ('seguir', 6),
#  ('gahyeon', 6),
#  ('unico', 5),
#  ('usa', 5),
#  ('reais', 5),
#  ('tanta', 5),
#  ('serio', 5),
#  ('feito', 5),
#  ('jeito', 5),
#  ('direto', 5),
#  ('coisas', 5),
#  ('x', 5),
#  ('melhor', 5),
#  ('ninguem', 5),
#  ('entrar', 5),
#  ('logo', 5),
#  ('fotos', 5),
#  ('erro', 5),
#  ('modo', 5),
#  ('gosta', 5),
#  ('desse', 5),
#  ('dias', 5),
#  ('algum', 5),
#  ('agr', 5),
#  ('acha', 5),
#  ('kkkkkkk', 5),
#  ('duas', 5),
#  ('jogos', 5),
#  ('chega', 5),
#  ('estava', 5),
#  ('whatsapp', 5),
#  ('re_apeixoto', 5),
#  ('egoismo', 5),
#  ('idiota', 5),
#  ('odiar', 5),
#  ('emprestar', 5),
#  ('otempo', 5),
#  ('mineirao', 5),
#  ('balancou', 5),
#  ('galo', 5),
#  ('canta', 5),
#  ('hino', 5),
#  ('pulmoes', 5),
#  ('festa', 5),
#  ('estourou', 5),
#  ('audio', 5),
#  ('cel', 5),
#  ('dinheiro', 5),
#  ('anos', 5),
#  ('nova', 5),
#  ('internet', 5),
#  ('entra', 5),
#  ('realidade', 5),
#  ('amg', 5),
#  ('homem', 5),
#  ('mo', 5),
#  ('cada', 5),
#  ('tirei', 5),
#  ('col', 5),
#  ('note', 5),
#  ('r', 5),
#  ('$', 5),
#  ('qualidade', 5),
#  ('passa', 5),
#  ('&', 5),
#  ('amar', 5),
#  ('lugares', 5),
#  ('segundo', 5),
#  ('fazem', 5),
#  ('nele', 5),
#  ('uol', 5),
#  ('seus', 5),
#  ('teve', 5),
#  ('parabens', 5),
#  ('tira', 5),
#  ('kkkk', 5),
#  ('agua', 5),
#  ('causa', 5),
#  ('unica', 5),
#  ('menos', 5),
#  ('dando', 5),
#  ('jrv_01', 5),
#  ('sinto-me', 5),
#  ('pagam', 5),
#  ('//t.co/qlarozyf8c', 5),
#  ('max', 5),
#  ('problema', 5),
#  ('nosso', 5),
#  ('sobre', 5),
#  ('respeito', 5),
#  ('06/11', 5),
#  ('l', 5),
#  ('foto/traducao', 5),
#  ('deurimkaecyeo', 5),
#  ('irma', 4),
#  ('jogar', 4),
#  ('fps', 4),
#  ('alguma', 4),
#  ('fez', 4),
#  ('falando', 4),
#  ('vaquinha', 4),
#  ('recuperar', 4),
#  ('segunda', 4),
#  ('ficando', 4),
#  ('tal', 4),
#  ('travando', 4),
#  ('trocar', 4),
#  ('bicho', 4),
#  ('tcc', 4),
#  ('sera', 4),
#  ('d', 4),
#  ('auge', 4),
#  ('fiz', 4),
#  ('deu', 4),
#  ('salvar', 4),
#  ('quase', 4),
#  ('dica', 4),
#  ('quebrou', 4),
#  ('verao', 4),
#  ('motivo', 4),
#  ('po', 4),
#  ('triste', 4),
#  ('igual', 4),
#  ('normal', 4),
#  ('dps', 4),
#  ('volta', 4),
#  ('5', 4),
#  ('pais', 4),
#  ('posso', 4),
#  ('mexe', 4),
#  ('epoca', 4),
#  ('pensei', 4),
#  ('destacou', 4),
#  ('brava', 4),
#  ('rlx', 4),
#  ('kkkkjj', 4),
#  ('//t.co/lpvgq9ywus', 4),
#  ('dar', 4),
#  ('infelizmente', 4),
#  ('foda', 4),
#  ('ir', 4),
#  ('amanha', 4),
#  ('namorada', 4),
#  ('vivo', 4),
#  ('oq', 4),
#  ('linda', 4),
#  ('amigo', 4),
#  ('diz', 4),
#  ('entre', 4),
#  ('baixar', 4),
#  ('voces', 4),
#  ('saber', 4),
#  ('amiga', 4),
#  ('pedir', 4),
#  ('1600', 4),
#  ('nota', 4),
#  ('live', 4),
#  ('dor', 4),
#  ('ligo', 4),
#  ('fiddle', 4),
#  ('//t.co/xjj7idig7z', 4),
#  ('cruzamento', 4),
#  ('pikachu', 4),
#  ('eoq_bangtan2', 4),
#  ('achei', 4),
#  ('piticos', 4),
#  ('divertindo', 4),
#  ('bts_twt', 4),
#  ('carro', 4),
#  ('agenda', 4),
#  ('esquerdista', 4),
#  ('tilt', 4),
#  ('espelho', 4),
#  ('saudade', 4),
#  ('cantando', 4),
#  ('esqueci', 4),
#  ('dizendo', 4),
#  ('focar', 4),
#  ('negro', 4),
#  ('novinho', 4),
#  ('prova', 4),
#  ('bola', 4),
#  ('ze', 4),
#  ('rafael', 4),
#  ('junto', 4),
#  ('sabia', 4),
#  ('materia', 4),
#  ('profissional', 4),
#  ('lucas', 4),
#  ('poder', 4),
#  ('fortaleza', 4),
#  ('rizia_cerqueira', 4),
#  ('p/', 4),
#  ('verem', 4),
#  ('cheio', 4),
#  ('microfone', 4),
#  ('imagine', 4),
#  ('rece', 4),
#  ('veio', 4),
#  ('epicos', 4),
#  ('klebber', 4),
#  ('toledo', 4),
#  ('ca', 4),
#  ('observa', 4),
#  ('gramado', 4),
#  ('quebrei', 4),
#  ('certeza', 4),
#  ('descobri', 4),
#  ('sabe', 4),
#  ('gravacao', 4),
#  ('falou', 4),
#  ('pessoas', 4),
#  ('samsung', 4),
#  ('camisa', 4),
#  ('tweet', 4),
#  ('marielle', 4),
#  ('franco', 4),
#  ('marcelofreixo', 4),
#  ('nossa', 4),
#  ('rindo', 4),
#  ('tive', 4),
#  ('liarsperk', 4),
#  ('salvou', 4),
#  ('//t.co/zhpo61wgr1', 4),
#  ('sacanagem', 4),
#  ('disponivel', 4),
#  ('dami', 4),
#  ('fuder', 3),
#  ('adesivo', 3),
#  ('hilu_hilu', 3),
#  ('cheguei', 3),
#  ('itens', 3),
#  ('roubaram', 3),
#  ('noteboo', 3),
#  ('horas', 3),
#  ('tv', 3),
#  ('saco', 3),
#  ('querer', 3),
#  ('faculdade', 3),
#  ('word', 3),
#  ('aberto', 3),
#  ('hahaha', 3),
#  ('puta', 3),
#  ('podia', 3),
#  ('estar', 3),
#  ('tt', 3),
#  ('kkkkkkkk', 3),
#  ('1', 3),
#  ('louca', 3),
#  ('tenha', 3),
#  ('escuro', 3),
#  ('sentido', 3),
#  ('entende', 3),
#  ('esperando', 3),
#  ("'", 3),
#  ('certo', 3),
#  ('nome', 3),
#  ('kkk', 3),
#  ('pega', 3),
#  ('atualizar', 3),
#  ('projeto', 3),
#  ('quantos', 3),
#  ('hj', 3),
#  ('passei', 3),
#  ('youtube', 3),
#  ('hein', 3),
#  ('perdeu', 3),
#  ('muita', 3),
#  ('valor', 3),
#  ('cena', 3),
#  ('4', 3),
#  ('quebra', 3),
#  ('mil', 3),
#  ('feliz', 3),
#  ('porem', 3),
#  ('lembrar', 3),
#  ('correndo', 3),
#  ('doida', 3),
#  ('fora', 3),
#  ('compro', 3),
#  ('sofa', 3),
#  ('manha', 3),
#  ('qnd', 3),
#  ('ajuda', 3),
#  ('completo', 3),
#  ('manda', 3),
#  ('hstyiesoul', 3),
#  ('negocio', 3),
#  ('laranja', 3),
#  ('wattpad', 3),
#  ('levar', 3),
#  ('falta', 3),
#  ('quarta', 3),
#  ('meninos', 3),
#  ('geral', 3),
#  ('abro', 3),
#  ('autoestima', 3),
#  ('desce', 3),
#  ('chao', 3),
#  ('acredito', 3),
#  ('favor', 3),
#  ('familia', 3),
#  ('inteiro', 3),
#  ('ajudem', 3),
#  ('guardo', 3),
#  ('lulurras', 3),
#  ('//t.co/fosf3uby3p', 3),
#  ('capinha', 3),
#  ('ligar', 3),
#  ('dms', 3),
#  ('ganhei', 3),
#  ('tomar', 3),
#  ('banho', 3),
#  ('bailey', 3),
#  ('numero', 3),
#  ('fizessem', 3),
#  ('cmg', 3),
#  ('acabar', 3),
#  ('errado', 3),
#  ('bb', 3),
#  ('quarto', 3),
#  ('luana', 3),
#  ('*', 3),
#  ('menor', 3),
#  ('troco', 3),
#  ('alem', 3),
#  ('realmente', 3),
#  ('postando', 3),
#  ('dao', 3),
#  ('falei', 3),
#  ('lucasmzanella', 3),
#  ('lancou', 3),
#  ('exterior', 3),
#  ('108', 3),
#  ('megapixels', 3),
#  ('maxima', 3),
#  ('ranking', 3),
#  ('dxomark', 3),
#  ('12', 3),
#  ('kkkkkkkkkkkk', 3),
#  ('acende', 3),
#  ('eaibrow_', 3),
#  ('sentem', 3),
#  ('perdendo', 3),
#  ('conforme', 3),
#  ('marav1lhosa', 3),
#  ('henrique', 3),
#  ('sendo', 3),
#  ('este', 3),
#  ('impossivel', 3),
#  ('retrovisor', 3),
#  ('momento', 3),
#  ('ficou', 3),
#  ('baby', 3),
#  ('sinceramente', 3),
#  ('prive', 3),
#  ('abre', 3),
#  ('dura', 3),
#  ('tb', 3),
#  ('dono', 3),
#  ('pegou', 3),
#  ('barulho', 3),
#  ('s', 3),
#  ('pontos', 3),
#  ('cade', 3),
#  ('pessima', 3),
#  ('januario', 3),
#  ('completamente', 3),
#  ('hoseok', 3),
#  ('forma', 3),
#  ('pois', 3),
#  ('outra', 3),
#  ('viram', 3),
#  ('doido', 3),
#  ('acham', 3),
#  ('ajudar', 3),
#  ('rapido', 3),
#  ('vamos', 3),
#  ('conseguem', 3),
#  ('android', 3),
#  ('versao', 3),
#  ('historia', 3),
#  ('cartao', 3),
#  ('meses', 3),
#  ('loja', 3),
#  ('seja', 3),
#  ('cheia', 3),
#  ('9', 3),
#  ('preto', 3),
#  ('psol50', 3),
#  ('parlamentar', 3),
#  ('bancada', 3),
#  ('crista', 3),
#  ('tripudiou', 3),
#  ('exigiu', 3),
#  ('corinthians', 3),
#  ('contra', 3),
#  ('estrela', 3),
#  ('vitimas', 3),
#  ('perseguicao', 3),
#  ('lembre', 3),
#  ('muscular', 3),
#  ('fase', 3),
#  ('forte', 3),
#  ('apago', 3),
#  ('liberar', 3),
#  ('fodida', 3),
#  ('ontem', 3),
#  ('baixa', 3),
#  ('ha', 3),
#  ('apagar', 3),
#  ('mjrtreze', 3),
#  ('cheiro', 3),
#  ('rapaz', 3),
#  ('paulo', 3),
#  ('bipolar', 3),
#  ('nois', 3),
#  ('luz', 3),
#  ('inferno', 3),
#  ('vento', 3),
#  ('cabelo', 3),
#  ('pelos', 3),
#  ('youtubers', 3),
#  ('favoritos', 3),
#  ('sorteando', 3),
#  ('brawler', 3),
#  ('lendario', 3),
#  ('skin', 3),
#  ('halloween', 3),
#  ('participar', 3),
#  ('basta', 3),
#  ('link', 3),
#  ('maistorcedoras', 3),
#  ('somos', 3),
#  ('desenvolvimento', 3),
#  ('objetivo', 3),
#  ('unir', 3),
#  ('aumentar', 3),
#  ('representatividade', 3),
#  ('feminina', 3),
#  ('dcatcherbr', 3),
#  ('minutos', 3),
#  ('nubank', 3),
#  ('gratis', 3),
#  ('immari_bitch', 2),
#  ('estudar', 2),
#  ('funcionando', 2),
#  ('adianta', 2),
#  ('aguenta', 2),
#  ('rodar', 2),
#  ('quanto', 2),
#  ('sorte', 2),
#  ('borelanjo', 2),
#  ('stickers', 2),
#  ('customizar', 2),
#  ('ubuntu', 2),
#  ('linux', 2),
#  ('//t.co/s5ucdks3au', 2),
#  ('levou', 2),
#  ('trava', 2),
#  ('desliguei', 2),
#  ('k', 2),
#  ('chegou', 2),
#  ('breve', 2),
#  ('diferente', 2),
#  ('chrome', 2),
#  ('//t.co/nzdxe0zxxh', 2),
#  ('bar', 2),
#  ('precisando', 2),
#  ('custo', 2),
#  ('beneficio', 2),
#  ('lmjsweetc', 2),
#  ('computador', 2),
#  ('kk', 2),
#  ('bah', 2),
#  ('resolvi', 2),
#  ('aguento', 2),
#  ('tera', 2),
#  ('hd', 2),
#  ('roda', 2),
#  ('hahahaha', 2),
#  ('travou', 2),
#  ('chato', 2),
#  ('lento', 2),
#  ('perdi', 2),
#  ('ultima', 2),
#  ('jesus', 2),
#  ('amem', 2),
#  ('fake', 2),
#  ('desligou', 2),
#  ('sozinho', 2),
#  ('sdds', 2),
#  ('queda', 2),
#  ('rica', 2),
#  ('usando', 2),
#  ('nd', 2),
#  ('brinquedo', 2),
#  ('enquanto', 2),
#  ('msc', 2),
#  ('sai', 2),
#  ('windows', 2),
#  ('deixe', 2),
#  ('lute', 2),
#  ('oswxld', 2),
#  ('ce', 2),
#  ('gosto', 2),
#  ('preparada', 2),
#  ('timedaandrea', 2),
#  ('deixei', 2),
#  ('chorando', 2),
#  ('perguntando', 2),
#  ('sexta', 2),
#  ('baixei', 2),
#  ('lendo', 2),
#  ('rosa', 2),
#  ('premium', 2),
#  ('pista', 2),
#  ('velho', 2),
#  ('comeca', 2),
#  ('vendi', 2),
#  ('brigadeiro', 2),
#  ('ligando', 2),
#  ('suporte', 2),
#  ('formatar', 2),
#  ('maximo', 2),
#  ('abas', 2),
#  ('irmao', 2),
#  ('pelada', 2),
#  ('altas', 2),
#  ('largar', 2),
#  ('fone', 2),
#  ('ouvido', 2),
#  ('morte', 2),
#  ('fe', 2),
#  ('roubo', 2),
#  ('planos', 2),
#  ('mexendo', 2),
#  ('mata', 2),
#  ('sentimento', 2),
#  ('dvd', 2),
#  ('desligar', 2),
#  ('pelicula', 2),
#  ('bebi', 2),
#  ('bebo', 2),
#  ('felicidade', 2),
#  ('sequestrador', 2),
#  ('vicio', 2),
#  ('//t.co/lt2qbksrsb', 2),
#  ('coracao', 2),
#  ('amigos', 2),
#  ('apaga', 2),
#  ('nossas', 2),
#  ('schafferjp', 2),
#  ('juniorf171', 2),
#  ('puxando', 2),
#  ('joga', 2),
#  ('seria', 2),
#  ('timidez', 2),
#  ('wefightt', 2),
#  ('site', 2),
#  ('colocar', 2),
#  ('navegador', 2),
#  ('trouxavcs', 2),
#  ('ei', 2),
#  ('tony', 2),
#  ('lindo', 2),
#  ('povo', 2),
#  ('pediu', 2),
#  ('astronomiaum', 2),
#  ('planicies', 2),
#  ('marcianas', 2),
#  ('registradas', 2),
#  ('rover', 2),
#  ('curiosity', 2),
#  ('incrivel', 2),
#  ('//t.co/nfncsoh5rs', 2),
#  ('pkfreestyleiro', 2),
#  ('//t.co/vvcwvxsvei', 2),
#  ('lgrillo2006', 2),
#  ('brunoteixeiraxx', 2),
#  ('xmfcklx', 2),
#  ('vascodagama', 2),
#  ('devendo', 2),
#  ('explicacao', 2),
#  ('auhahuau', 2),
#  ('vivi_scans', 2),
#  ('guilhermeboulos', 2),
#  ('abraco', 2),
#  ('obs', 2),
#  ('esperou', 2),
#  ('pacientemente', 2),
#  ('giumsantos', 2),
#  ('vivendo', 2),
#  ('cerebro', 2),
#  ('enfrentamento', 2),
#  ('postei', 2),
#  ('stories', 2),
#  ('prometi', 2),
#  ('jogaria', 2),
#  ('enfrentar', 2),
#  ('tulla', 2),
#  ('cuspindo', 2),
#  ('lifestyle', 2),
#  ('desliga', 2),
#  ('cigarro', 2),
#  ('//t.co/cdx11o46lw', 2),
#  ('edspellegrini', 2),
#  ('angelalbie', 2),
#  ('senti', 2),
#  ('caindo', 2),
#  ('escada', 2),
#  ('grava', 2),
#  ('dourado', 2),
#  ('viuva', 2),
#  ('rapazeada', 2),
#  ('on', 2),
#  ('streamar', 2),
#  ('morrendo', 2),
#  ('cam', 2),
#  ('tarde', 2),
#  ('lt', 2),
#  ('gameplay', 2),
#  ('criminosa', 2),
#  ('diria', 2),
#  ('jovem', 2),
#  ('mono', 2),
#  ('//t.co/txetvf1twk', 2),
#  ('pizzz2009', 2),
#  ('hfloret', 2),
#  ('focou', 2),
#  ('nandoohliimah', 2),
#  ('revelar', 2),
#  ('identidade', 2),
#  ('malditopt', 2),
#  ('biasscosta', 2),
#  ('//t.co/iljmynrmtj', 2),
#  ('qando', 2),
#  ('enzo_gb09', 2),
#  ('direcao', 2),
#  ('deputados', 2),
#  ('//t.co/yd9ca1qas1', 2),
#  ('colegio', 2),
#  ('preta', 2),
#  ('trancada', 2),
#  ...]
