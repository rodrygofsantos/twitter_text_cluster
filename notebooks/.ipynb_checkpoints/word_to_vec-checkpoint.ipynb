# %%
import os
from gensim.models import Word2Vec
from unidecode import unidecode
import string
import re
from sklearn.decomposition import PCA
from matplotlib import pyplot
from sklearn.manifold import TSNE
import numpy as np
import multiprocessing
# %matplotlib inline

# %%
corpus_path = '../data/2019-11-10 13:29:13.766706/filtered_tweets.txt'
graphs_path = '../data/2019-11-10 13:29:13.766706/graphics/'

# %%
#importando o corpus
raw_text = ''
with open(corpus_path, 'r') as file:
    raw_text = file.readlines()
    file.close()
    
raw_text = [e.rstrip() for e in raw_text]

print(raw_text)
# Out:
# ['toda vez bosolnaro fala impressao deu trago tolete m rda', 'jairbolsonaro presidente bosolnaro rede social facebook gruppo flamengo tundos bloquiando ditadura pt stf possou fala grupo', 'clauber01095735 folha folha poder moro bosolnaro', 'lucasportelaa pq lula ta solto thread vc n entende nada direito politica sabe aconteceu pais', 'bolsominion amigo irmao pedindo socio torcedor emprestado pq quer gastar dinheiro entrada estadiofodase empresto', 'julioal53442452 miltonneves deb mental presidente bosolnaro saber falar sabe tava casa 58 vai dizer bebe cachaca problema bebe', 'lanaramoreira peterjordan100 lanaramoreira kkkkk coitada precisa estudar presidente presidiario esquerda chora manda pagar bolsa manda mail dizendo opressor ah esqueci analfabeto hahahaha', 'mariahbolsonaro iludam esquerdinhas bandido estimacao vcs solto absolvido fiquem empolgados pois pr', 'salsaparrilha4 vem burro', 'leranden neomauriciojr danilo78910 leandroruschel certeza povo importa b chama rua import', 'resustenido movimento negro fala questao prisional ha tempo encarceramento massa so quero ver problematizacao', 'concordo lava jato pode abater gracas descoberta quadrilha petista montada lula dirceu', 'claudiocmaciel bom dia favor vejam pergunto stf oficial sentido vendo lideres organizacoes criminosas s', 'luansantana frio barriga dar grande passo chega hoje muitas pessoas todo brasil bom enem todos voce', 'darioberger soube senhor indeciso sobre pec 410 18 espero verdade informacao', 'adriana accorsi lula preso bracos povo brasileiro lula', 'afccontador nova reportagem the intercept brasil escrita joao filho base mensagens trocadas integrantes forc', 'istauroelyades crismenshova psdboficial cris cara assim voce estraga velorio juntar fhc joseserra geraldoalckmin', 'mapa segunda instancia prisao2ainstanciaagoraeste mapa previo votacao camara sobre pec 410 18 frente agora falta articularmos centrao esquerda racional psb senador deputado estao indecisos cobre', 'camilaturtelli gabriela bilo1 conversamos alexandre frota entrevista diz bolsonaro tao incompetente', 'eduardomoreira nenhum canal tv isento ter transmitido discurso lula hoje transmitiram porque mundo inteiro queria v', 'concurso publico ja ministros supremo conselheiros tribunais contas uniao estados ate cargos importantes brasil vao ficar mao indicacoes concurso publico presente vitalicio advogado amigo politico vergonha nacional', 'stf vergonha nacional', 'rhpozzobon carlazambelli17 stf vergonha nacional', 'freitas6388 stf nega liberdade preso pesca ilegal pescou nada', 'le monde decisao stf representa tapa cara ex juizinho sergio moro', 'vocalista lider mastodon brent hinds namorada brasileira raisa moreno comemoraram instagram liberdade ex presidente lula postaram videos filtros vermelhos rostos mensagem lula livre mastodon brenthinds lulalivre', 'renovamidia ta cadeia presidente bosolnaro', 'genpaulochagas desventurados desprovidos carater porque sera reino trevas lula lugar inferno', 'feliz domingo hiloqueremos medusa albarecheot2018 top20 webchart radioradicalpt radioradicalpt', 'antagonista stf oficial vergonha nacional sao doutrinados favorecerem elite brasileira', 'meuraiz pau cu bozo lula bagulho dia 23', 'vemprarua br obrigados aceitar tudo stf nus empoem', 'brasil experimentando maiores desindustrializacoes historia economia', 'pcyhyo voce esquerda direita eeeeewww centro evoluidaahhhpetista', 'boa tarde presidente lulaoficial', 'pt fez 6 x 5 pt ganhou saltar lula crise brasil culpado bosolnaro', 'niltonfelipe lider psl acusa bolsonaro comprar votos anuncia denuncia cassacao seis deputados', 'lets dex lembrando coisa prisao 2deg instancia manteve ha 2 anos causa voto zavasckiem seguida infor', 'lachampt58 humbertoreisjr 6 sinistros stf votaram favor malfeitores sao responsaveis atos libertaram todo assassinato todo quebra quebra deve ser responsabilidade criminal desses ministros', 'oieusouowilliam vendo varios perfis bandeira brasil nome dizem patriotas extrema direita segui ...

# %%
word_list = [e.split(' ') for e in raw_text]


#treinando modelo
model_w2v = Word2Vec(
    word_list, 
    window=5, #vizinhos checados
    min_count= multiprocessing.cpu_count(), 
    workers=5,
    size= 200,
    
)
#palavras dentro do modelo
words_in_w2v = list(model_w2v.wv.vocab)


print(model_w2v)
print(words_in_w2v)
# Out:
# Word2Vec(vocab=1310, size=200, alpha=0.025)
# ['toda', 'vez', 'bosolnaro', 'fala', 'deu', 'm', 'jairbolsonaro', 'presidente', 'rede', 'social', 'facebook', 'flamengo', 'bloquiando', 'ditadura', 'pt', 'stf', 'possou', 'grupo', 'folha', 'poder', 'moro', 'lucasportelaa', 'pq', 'lula', 'ta', 'solto', 'thread', 'vc', 'n', 'entende', 'nada', 'direito', 'politica', 'sabe', 'aconteceu', 'pais', 'bolsominion', 'amigo', 'socio', 'quer', 'dinheiro', 'saber', 'falar', 'tava', 'casa', '58', 'vai', 'dizer', 'bebe', 'problema', 'lanaramoreira', 'kkkkk', 'precisa', 'estudar', 'presidiario', 'esquerda', 'manda', 'dizendo', 'ah', 'bandido', 'estimacao', 'vcs', 'pois', 'pr', 'vem', 'burro', 'leandroruschel', 'certeza', 'povo', 'importa', 'b', 'chama', 'rua', 'movimento', 'negro', 'questao', 'ha', 'tempo', 'massa', 'so', 'quero', 'ver', 'concordo', 'lava', 'jato', 'pode', 'gracas', 'descoberta', 'quadrilha', 'petista', 'dirceu', 'bom', 'dia', 'favor', 'vejam', 'pergunto', 'oficial', 'vendo', 'lideres', 'organizacoes', 'criminosas', 's', 'dar', 'grande', 'passo', 'chega', 'hoje', 'muitas', 'pessoas', 'todo', 'brasil', 'todos', 'voce', 'soube', 'senhor', 'sobre', 'pec', '410', '18', 'espero', 'verdade', 'preso', 'bracos', 'brasileiro', 'nova', 'reportagem', 'the', 'intercept', 'filho', 'mensagens', 'integrantes', 'crismenshova', 'psdboficial', 'cara', 'assim', 'fhc', 'mapa', 'segunda', 'instancia', 'prisao2ainstanciaagoraeste', 'previo', 'votacao', 'camara', 'frente', 'agora', 'falta', 'senador', 'deputado', 'estao', 'indecisos', 'alexandre', 'frota', 'entrevista', 'diz', 'bolsonaro', 'tao', 'eduardomoreira', 'nenhum', 'canal', 'tv', 'isento', 'ter', 'discurso', 'porque', 'mundo', 'inteiro', 'queria', 'concurso', 'publico', 'ja', 'ministros', 'supremo', 'uniao', 'estados', 'ate', 'importantes', 'vao', 'ficar', 'mao', 'advogado', 'politico', 'vergonha', 'nacional', 'carlazambelli17', 'nega', 'liberdade', 'pesca', 'ilegal', 'pescou', 'le', 'monde', 'decisao', 'representa', 'tapa', 'ex', 'juizinho', 'sergio', 'lider', 'mastodon', 'namorada', 'brasileira', 'livre', 'lulalivre', 'renovamidia', 'cadeia', 'carater', 'sera', 'lugar', 'inferno', 'feliz', 'domingo', 'radioradicalpt', 'antagonista', 'sao', 'elite', 'pau', 'cu', 'bozo', 'vemprarua', 'br', 'tudo', 'historia', 'economia', 'direita', 'eeeeewww', 'centro', 'boa', 'lulaoficial', 'fez', '6', 'x', '5', 'ganhou', 'crise', 'culpado', 'psl', 'comprar', 'votos', 'anuncia', 'deputados', 'lets', 'dex', 'lembrando', 'coisa', 'prisao', '2', 'anos', 'causa', 'voto', 'seguida', 'votaram', 'responsaveis', 'atos', 'assassinato', 'quebra', 'deve', 'ser', 'responsabilidade', 'desses', 'varios', 'nome', 'dizem', 'extrema', 'ritalisauskas', 'apos', 'soltura', 'passou', 'incitar', 'violencia', 'contra', 'instituicoes', 'mundial', 'dificil', 'mostra', 'p', 'haddaddebochado', 'militares', 'ainda', 'bem', 'recado', 'davialcolumbre', 'aprovada', 'u', 'venezuela', '40', 'votei', 'socorro', 'oodiodobem', 'blogdopim', 'conseguiu', 'criar', 'fazer', 'alem', 'tornou', 'poucos', 'paises', 'fica', 'morrer', 'parabens', 'democracia', 'judiciario', 'gente', 'cd', 'entregue', 'sindico', 'familia', 'entregou', 'prova', 'mprj', 'pericia', 'forca', 'rizethj', 'ira', 'cair', 'ficha', 'militancia', 'verde', 'perdeu', 'volta', 'area', 'alma', 'perfeito', 'copa', 'gt', 'esquece', 'vale', 'pouco', 'maior', 'torcida', 'rs', 'ouro', 'ggreenwald', 'turma', 'theinterceptbr', 'alguem', 'tipo', 'pessoa', 'dois', 'extremos', 'passando', 'jornalistas', 'recebem', 'premio', 'justica', 'fn7k', 'maia', 'via', 'mbl', 'paulista', 'cpi', 'toga', 'comecou', 'pararam', 'gilmarmendes', 'isentoes2', 'muitos', 'politicos', 'eleicao', 'fake', 'news', 'branca', 'poderia', 'mesma', 'opiniao', 'internet', 'jair', 'criminoso', 'condenado', 'colocam', 'lados', 'opostos', 'entendedor', 'estadao', 'mae', 'conhece', 'afirma', 'va', 'adrialcantara17', 'passear', 'ruas', 'corruptos', 'poderosos', 'ricos', 'soltos', 'enquanto', 'globo', 'chamou', 'vivo', 'larapio', 'usou', 'jatinho', 'siteptbr', 'aqui', 'video', ' ...

# %%
def print_results(model, search_tokens):
    #se for uma palavra
    args = search_tokens.split(' ')

    
    print(search_tokens)
    if len(args) == 1:
        if search_tokens not in words_in_w2v:
            return print('Error - words out of dict')
        for e in model_w2v.wv.most_similar(search_tokens)[:10]:
            print(e)
            print('-'*20)
        print('#'*20)
    
    #se for uma frase
    if len(args) > 1:
        print("Further away from the mean: {0}".format(model.wv.doesnt_match(args)))
        if len(args) == 2:
            print("Similarity: {0}".format(model.wv.similarity(args[0], args[1])))
        print('#'*20)

# %%
print_results(model_w2v, 'pec')
# Out:
# pec
# ('lula', 0.6516968011856079)
# --------------------
# ('brasil', 0.6423418521881104)
# --------------------
# ('so', 0.6123542785644531)
# --------------------
# ('ja', 0.608491063117981)
# --------------------
# ('sao', 0.605750322341919)
# --------------------
# ('ser', 0.6007635593414307)
# --------------------
# ('pt', 0.600189208984375)
# --------------------
# ('prisao', 0.5953267812728882)
# --------------------
# ('stf', 0.585867166519165)
# --------------------
# ('voce', 0.580469012260437)
# --------------------
# ####################

# %%
print_results(model_w2v, 'dilma paulo')
# Out:
# dilma paulo
# Further away from the mean: paulo
# Similarity: 0.14363709092140198
# ####################
# /home/albrigs/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
#preparando dados para gráfico
search_key = 'presidente'


embeddings, words = [], []

for similar_word, _ in model_w2v.most_similar(search_key):        
    words.append(similar_word)
    embeddings.append(model_w2v[similar_word])
    
        
print(words)
# Out:
# ['brasil', 'moro', 'lula', 'so', 'ja', 'prisao', 'ser', 'stf', 'vergonha', 'pt']
# /home/albrigs/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   import sys
# /home/albrigs/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
embeddings = np.array(embeddings)
print(embeddings.shape)

tsne_model_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=600, random_state=3)

embeddings_2d = np.array(tsne_model_2d.fit_transform(embeddings))
# Out:
# (10, 200)

# %%
plt.figure(figsize=(16, 9))
x = embeddings[:, 0]
y = embeddings[:, 1]
plt.scatter(x, y, label = search_key)
for i, e in enumerate(words):
    plt.annotate(e, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                 textcoords='offset points', ha='right', va='bottom', size=8)
plt.legend(loc=4)
plt.title('Near to {0}'.format(search_key))
plt.grid(True)
plt.savefig(graphs_path+'_tnse'+search_key+'.png', format='png', dpi=200)
plt.show()
