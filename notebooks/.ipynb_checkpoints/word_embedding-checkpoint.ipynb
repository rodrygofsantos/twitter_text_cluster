# %%
import os
from gensim.models import Word2Vec
from unidecode import unidecode
import string
from matplotlib import pyplot
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
import multiprocessing
import networkx as nx 
import matplotlib.pyplot as plt
import numpy as np
import nltk
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import get_tmpfile


# %matplotlib inline
# Out:
# /home/natan/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/natan/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/natan/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
corpus_path = '../data/2019-11-11 09:38:45.985811/filtered_tweets.txt'
graphs_path = '../data/2019-11-11 09:38:45.985811/graphics/'

# %%
#importando o corpus
raw_text = ''
with open(corpus_path, 'r') as file:
    raw_text = file.readlines()
    file.close()
    
raw_text = [e.rstrip() for e in raw_text]

print(raw_text[:500])
# Out:
# ['bom dia proletariado sulamericano dorme onda progressista america latina acorda golpe militar bolivia reformismo beco saida conciliacao so rabo leiam marx organizem bebam agua boa pa nois golpeenbolivia lulalivre', 'brazilfight vai humilhar stf pois todos membros sao funcionarios particulares lacaios comprados peso ouro tudo acontece la tudo ensaiado combinado antes voce vota assim outro vota assado assim diante artigo142', 'josiasteofilo lula politicos individuos cinicos corruptos mundo steve bannon', '125 dias dnaworldtour brasil backstreetboys ktbspa', 'deputadofederal lava jato moro usaram dinheiro contribuinte brasileiro estrutura estado interferir vida interna', 'themingau fala lula ultimamente resolvi falar lula tambem vou falar lula mamifero lulaofic', 'vergonha nacional continua bom dia brasil chico pinheiro compartilhando gente vergonha', 'anee aesquerda ignorar lindo ver lulalivre', 'alvarodias senadora juiza selma ja entregou relatorio favoravel pec segunda instancia projeto pronto ser votado n', 'cresci casa cheia adesivos pt', 'haviam deputados senadores indecisos aprovar pec 410 18 desta manifestacao ainda sim decidirem dar voto aprovacao entao estao condenados nunca nunca reelegerem vao merecer jamais respeito povo brasileiro', 'uli cassilva limadoc pais ordem regras vira bagunca falta brasil', 'lulalivre favor amooooooooooooodesculpa gay', 'acidadeplantao mortalidade infantil brasil aumentou vertiginosamente apos golpe estado diferente lulaoficial dilmab', 'bolsonaro diz voto impresso impediria fraude eleicoes bolivia onde voto impresso via', 'zehdeabreu homem confianca jair bolsonaro citado audio opositores tentam golpe contra evo bolivia revista', 'jairbolsonaro governo bolsonaro primeira semana novembro 1 formatura 500 novos policiais federais', 'mblivrego manifestacao goiania favor lava toga pec 410 18', 'maisabaria voce abriu boca causa aecio 39 kg po laranjal psl queiroz porteiro qu', 'fabricio rebelo 1 caso congresso fato pretenda viabilizar minimamente cumprimento penas apos julgamento segunda inst', 'dorafigueiredo entendi bolsonaro quer acabar humanidade', 'blogdopim voces acham so esquerda acordem amigos diz senadora soraya thronicke psl sobre lerdeza pro', 'impeachmentgilmarmendes stfvergonha nacional', 'darioberger soube senhor indeciso sobre pec 410 18 espero verdade informacao', 'silvathiagohs printei apagar olhem escreveu bosta quer ser presidente brasil apoiando golpe mil', 'filippeirrazbal pgr augusto aras indicado parte acordao indicado alberto fraga antigo lider bancada d', 'pode ser votada hoje ccj camara pec 410 18 proposta emenda coloca texto constitucional possibilidade prisao apos condenacao segunda instancia caso receba parecer favoravel ainda precisa passar duas votacoes tanto camara quanto senado', 'lpbragancabr estarei hoje paulista apoiando todas iniciativas resultem permitir prisao apos condenacao segunda instancia', 'paulomartins10 lula disse saiu cadeia ainda esquerda maneira demonstrar cadeia recupera ninguem', 'gilmarmendes vergonha nacional', 'marciom02035740 lacombe reafirmo apoio lava jato ministro sergio moro conexao politica', 'leoarlac dou parabens solta lula lulalivre', 'stf ja passou limites tratando povo palhaco ficamos pagando salarios astronomicos bandidos soltarem todos corruptos impeachmentgilmarmendes', 'alcalejon mae virando ver duplas ja tv quis passar audiencia sim publico quer ver sim', 'marciotobias6 thread denunciabolsonaro dias toffoli andre mendonca tentam destruir deltan dallagnol lava jatoo bolsonaro', 'macielclaudio pec 410 18e la vem nhonho novamente protagonista destinos nacao montado jumento vermelho foice mart', 'alexandrejosro5 deu evitar colocar video todos voces vejam absurdo sendo elaborado vez p', 'jr ferreira livrepensandor rogerio1929 ler estudar bom eua mudaram constituicao poder ter presidente sempre escolhido povo repetidamente roosevelt', 'heldersalomao lula pode velar irmao consolar familia perdas porque preso agora lula podia ir cas ...

# %%
#preparando a lista de palavras
word_list = [e.split(' ') for e in raw_text]

nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('portuguese')
stop_words.extend(["ja", "assim", "nao", "pra", "q", "voce", "sobre","ser", "so", "vai", "ate", "tao", 'so'])

word_list = [ [w for w in e if w not in stop_words] for e in word_list] #filtrando o texto

print(word_list[15])
print("nao" in word_list)

# %%
#treinando modelo word2vec
model_w2v = Word2Vec(
    word_list, 
    window=5, #vizinhos checados
    min_count= multiprocessing.cpu_count(), 
    workers=5,
    size= 200,
    sg = 0
)

#palavras dentro do modelo
words_in_w2v = list(model_w2v.wv.vocab)[:]


print(model_w2v)
print(words_in_w2v[:30])
# Out:
# ['zehdeabreu', 'homem', 'confianca', 'jair', 'bolsonaro', 'citado', 'audio', 'opositores', 'tentam', 'golpe', 'contra', 'evo', 'bolivia', 'revista']
# False
# [nltk_data] Downloading package stopwords to /home/natan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#salvando arquivo na pasta de arquivos temporários
file_w2v = get_tmpfile("w2v")
model_w2v.save(file_w2v)
model_w2v = Word2Vec.load(file_w2v) #carregando (verificando integridade arquivo salvo)

# %%
#imprimindo palavras próximas
def print_results(model, *args):
    print(args)
    if len(args) == 1:
        arg = str(*args)
        if arg not in model.wv.vocab:
            return print('Error - words out of dict')
        print('Most  common word near is:')
        for e in model_w2v.wv.most_similar(arg)[:10]:
            print(e)
            print('-'*20)
        print('#'*20)
    
    #se for uma frase
    if len(args) > 1:
        print("Further away from the mean: {0}".format(model.wv.doesnt_match(args)))
        if len(args) == 2:
            print("Similarity: {0}".format(model.wv.similarity(args[0], args[1])))
        print('#'*20)

# %%
print_results(model_w2v, 'pec')
# Out:
# ('pec',)
# Most  common word near is:
# ('presidente', 0.5841286182403564)
# --------------------
# ('stf', 0.5395362973213196)
# --------------------
# ('prisao', 0.5193470120429993)
# --------------------
# ('tambem', 0.49798640608787537)
# --------------------
# ('instancia', 0.48902127146720886)
# --------------------
# ('moro', 0.4793904423713684)
# --------------------
# ('lula', 0.47919800877571106)
# --------------------
# ('porque', 0.4652772843837738)
# --------------------
# ('vaza', 0.464886873960495)
# --------------------
# ('povo', 0.4615943133831024)
# --------------------
# ####################

# %%
print_results(model_w2v, 'dilma', 'paulo')
# Out:
# ('dilma', 'paulo')
# Further away from the mean: paulo
# Similarity: 0.09719287604093552
# ####################
# /home/natan/anaconda3/lib/python3.7/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
#preparando dados para gráfico

search_key = 'presidente'
embeddings, words = [], []

for similar_word, _ in model_w2v.most_similar(search_key):        
    words.append(similar_word)
    embeddings.append(model_w2v[similar_word])
    
print(words)

embeddings = np.array(embeddings)
print(embeddings.shape)
# Out:
# ['pec', 'stf', 'moro', 'prisao', 'sao', 'porque', 'instancia', 'vaza', '18', 'contra']
# (10, 200)
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
tsne_model_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=600, random_state=3)

embeddings_2d = np.array(tsne_model_2d.fit_transform(embeddings))

plt.figure(figsize=(9, 6))
x = embeddings[:, 0]
y = embeddings[:, 1]
plt.scatter(x, y, label = search_key)

for i, e in enumerate(words):
    plt.annotate(e, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                 textcoords='offset points', ha='right', va='bottom', size=8)

plt.legend(loc=4)
plt.title('Near to {0}'.format(search_key))
plt.grid(True)
plt.savefig(graphs_path+'_tnse'+search_key+'.png', format='png', dpi=200)

plt.show()

# %%
#grafico de rede
net_term = 'jato'
net_graph = nx.Graph()

net_graph.add_node(net_term)

neigbors = model_w2v.wv.most_similar(net_term) #vizinhos

net_graph.add_weighted_edges_from([(net_term, x, y) for x,y in neigbors if y> 0.5] )

#adicionando vizinhos e mostrando relações indiretas
for e in neigbors:
    net_graph.add_weighted_edges_from([(e[0], x, y) for x,y in model_w2v.most_similar(e[0])])

cols = ['r']*len(net_graph.nodes()); cols[list(net_graph.nodes()).index(net_term)]='b'
pos = nx.spring_layout(net_graph, iterations=100)


nx.draw_networkx(
    net_graph,
    pos=pos, #posições
    node_color=cols, #cores
    node_size=100, #tamanho do marcador
    alpha=0.7, 
    font_size=16,
)
# Out:
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   del sys.path[0]
# /home/natan/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:563: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/natan/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning:
# The is_numlike function was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use isinstance(..., numbers.Number) instead.
#   if cb.is_numlike(alpha):

# %%
#DOC2VEC

# %%
#preparando documentos
docs = [TaggedDocument(e, [i]) for i, e in enumerate(word_list)]

#treinando modelo
model_d2v= Doc2Vec(
    documents=docs,
    vector_size= 5,
    window= 5,
    min_count= 1,
    workers= 4
)

# %%
#salvando arquivo na pasta de arquivos temporários
file_d2v = get_tmpfile("d2v")
model_d2v.save(file_d2v)
model_d2v = Doc2Vec.load(file_d2v)

# %%
model_d2v.most_similar('aniquilar')
# Out:
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('livre', 0.9944735765457153),
#  ('golpedeestadoenbolivia', 0.9930667877197266),
#  ('omisso', 0.9893830418586731),
#  ('mvb', 0.9885964393615723),
#  ('jdoriajr', 0.9849634170532227),
#  ('petista', 0.9839142560958862),
#  ('coracao', 0.9793277382850647),
#  ('elegeu', 0.9768145084381104),
#  ('esquerdolindos', 0.9761495590209961),
#  ('linha', 0.9688964486122131)]

# %%
model_d2v.most_similar_cosmul('bolsonaro')
# Out:
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   """Entry point for launching an IPython kernel.
# [('pol', 0.9974292516708374),
#  ('repetidamente', 0.992222785949707),
#  ('tregua', 0.9870491623878479),
#  ('assista', 0.9864438772201538),
#  ('2011', 0.9824543595314026),
#  ('lavatogaja', 0.9803670644760132),
#  ('moderado', 0.9755944013595581),
#  ('fraudadas', 0.9740694761276245),
#  ('exercito', 0.972564697265625),
#  ('orgao', 0.9721682667732239)]

# %%
model_d2v.similarity('presidente', 'lula')
# Out:
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.055065393

# %%
model_d2v.similarity('presidente', 'bolsonaro')
# Out:
# /home/natan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# -0.119832516

# %%
model_d2v.wv.most_similar('bolsonaro')
# Out:
# [('pol', 0.9948604106903076),
#  ('repetidamente', 0.9844474792480469),
#  ('tregua', 0.9741002321243286),
#  ('assista', 0.9728896617889404),
#  ('2011', 0.964910626411438),
#  ('lavatogaja', 0.9607360363006592),
#  ('moderado', 0.951190710067749),
#  ('fraudadas', 0.9481408596038818),
#  ('exercito', 0.9451313018798828),
#  ('orgao', 0.9443384408950806)]

# %%
print(list(model_w2v.wv.vocab))
# Out:
# ['bom', 'dia', 'america', 'latina', 'golpe', 'militar', 'bolivia', 'saida', 'rabo', 'leiam', 'agua', 'boa', 'lulalivre', 'brazilfight', 'stf', 'pois', 'todos', 'sao', 'tudo', 'acontece', 'la', 'antes', 'vota', 'outro', 'lula', 'politicos', 'corruptos', 'mundo', 'steve', 'bannon', 'dias', 'brasil', 'deputadofederal', 'lava', 'jato', 'moro', 'usaram', 'dinheiro', 'brasileiro', 'estado', 'vida', 'fala', 'falar', 'tambem', 'vou', 'vergonha', 'nacional', 'continua', 'chico', 'gente', 'ignorar', 'lindo', 'ver', 'alvarodias', 'senadora', 'favoravel', 'pec', 'segunda', 'instancia', 'pronto', 'n', 'casa', 'cheia', 'pt', 'deputados', 'senadores', 'indecisos', 'aprovar', '410', '18', 'desta', 'manifestacao', 'ainda', 'sim', 'dar', 'voto', 'aprovacao', 'entao', 'estao', 'condenados', 'nunca', 'vao', 'jamais', 'respeito', 'povo', 'uli', 'cassilva', 'pais', 'ordem', 'regras', 'vira', 'falta', 'favor', 'acidadeplantao', 'apos', 'diferente', 'lulaoficial', 'bolsonaro', 'diz', 'impresso', 'fraude', 'eleicoes', 'onde', 'via', 'homem', 'jair', 'citado', 'audio', 'opositores', 'tentam', 'contra', 'evo', 'revista', 'jairbolsonaro', 'governo', 'primeira', 'semana', 'novembro', '1', '500', 'novos', 'toga', 'abriu', 'boca', 'causa', 'aecio', 'po', 'laranjal', 'psl', 'queiroz', 'porteiro', 'qu', 'caso', 'congresso', 'fato', 'julgamento', 'inst', 'entendi', 'quer', 'acabar', 'blogdopim', 'voces', 'acham', 'esquerda', 'acordem', 'pro', 'impeachmentgilmarmendes', 'senhor', 'espero', 'verdade', 'informacao', 'apagar', 'bosta', 'presidente', 'apoiando', 'mil', 'filippeirrazbal', 'pgr', 'augusto', 'aras', 'indicado', 'parte', 'acordao', 'alberto', 'fraga', 'antigo', 'lider', 'bancada', 'd', 'pode', 'votada', 'hoje', 'ccj', 'camara', 'proposta', 'coloca', 'texto', 'constitucional', 'possibilidade', 'prisao', 'condenacao', 'precisa', 'passar', 'duas', 'votacoes', 'tanto', 'quanto', 'senado', 'estarei', 'paulista', 'todas', 'permitir', 'disse', 'saiu', 'cadeia', 'maneira', 'ninguem', 'gilmarmendes', 'lacombe', 'reafirmo', 'apoio', 'ministro', 'sergio', 'politica', 'parabens', 'solta', 'passou', 'palhaco', 'pagando', 'bandidos', 'tv', 'audiencia', 'publico', 'thread', 'toffoli', 'andre', 'mendonca', 'deltan', 'dallagnol', 'vem', 'novamente', 'vermelho', 'alexandrejosro5', 'deu', 'evitar', 'colocar', 'video', 'vejam', 'absurdo', 'sendo', 'vez', 'p', 'eua', 'constituicao', 'poder', 'ter', 'sempre', 'heldersalomao', 'familia', 'porque', 'preso', 'agora', 'podia', 'ir', 'nessa', 'hora', 'clara', 'gilmar', 'mendes', 'maior', 'ameaca', '57', 'milhoes', 'deixar', 'pauta', 'paulo', '2009', 'fernando', '2016', 'dilma', 'kkkkkk', 'nd', 'gosto', 'cara', 'sala', 'pq', 'naruto', 'agr', 'fica', 'fico', 'olha', 'general', 'pede', 'populacao', 'votar', 'impeachment', 'ministros', 'chamar', 'defensor', 'ditadura', 'amigo', 'milicianos', 'mesma', 'aqui', 'bozo', 'eleito', 'menos', '11', 'meses', 'flaviodino', 'exemplo', 'condenado', 'culpado', 'va', 'pena', 'parece', 'sera', 'apenas', 'gfiuza', 'oficial', 'politico', 'napoleao', 'cumplice', 'acordo', 'triplex', 'quero', 'alem', 'anulacao', 'sf', 'trata', 'nada', 'pessoal', 'nisso', 'existe', 'negocio', 'inclusive', 'ha', 'nome', 'renuncia', 'morales', 'vive', 'junto', 'vice', 'sophiepieretti', 'enquanto', 'unir', 'peeeedd', 'wolfxstilinsk', 'felipeneto', 'inteligente', 'ross', 'joey', 'molusco', 'desculpa', 'julgar', 'entendo', 'completamente', 'vamos', 'ajudar', 'pacote', 'anti', 'crime', 'proteger', 'queremos', 'bandido', 'governador', 'primeiro', 'minas', 'liberdade', 'douglasgarcia', 'lixo', 'transito', 'agu', 'bem', 'sabido', 'importante', 'tentar', 'amansar', 'feras', 'tentativa', 'resposta', 'leonardoboff', 'indigena', 'evoespueblo', 'onu', 'crise', 'justica', 'provar', 'metem', 'medo', 'venha', 'quiser', 'estaremos', 'filhos', 'desse', 'luciano', 'mentira', 'fake', 'news', 'ouvido', 'merece', 'molote', 'defende', 'tweet', 'fraudes', 'luh', 'roma', 'melhor', 'gado', 'pensa', 'nele', 'toda', 'classe', 'alias', 'objetivo',  ...
